# %% [markdown]
# # Data retrieval through API

# %% [markdown]
# Based on NCHS - Leading Causes of Death: United States:
# This dataset presents the age-adjusted death rates for the 10 leading causes of death in the United States beginning in 1999.Total number of records are 10,886. For the project, records from 2010 through 2017 have been included reducing the sample size to 4576 records by applying filtering ang paging criteria to the endpoint.
# Data are based on information from all resident death certificates filed in the 50 states and the District of Columbia using demographic and medical characteristics. Age-adjusted death rates (per 100,000 population) are based on the 2000 U.S. standard population. Populations used for computing death rates after 2010 are postcensal estimates based on the 2010 census, estimated as of July 1, 2010. Rates for census years are based on populations enumerated in the corresponding censuses. Rates for non-census years before 2010 are revised using updated intercensal population estimates and may differ from rates previously published.
# Causes of death classified by the International Classification of Diseases, Tenth Revision (ICD–10) are ranked according to the number of deaths assigned to rankable causes. Cause of death statistics are based on the underlying cause of death.

# %%
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup
#from sodapy import Socrata

# %%
url = "https://data.cdc.gov/resource/bi63-dtpu.json?$where=year>=2010&$limit=4600"

# %%
loaded_json = requests.get(url).json()
loaded_json
# Out:
# [{'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Alabama',
#   'deaths': '2394',
#   'aadr': '49.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Alaska',
#   'deaths': '366',
#   'aadr': '58.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Arizona',
#   'deaths': '3018',
#   'aadr': '46.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Arkansas',
#   'deaths': '1461',
#   'aadr': '49.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'California',
#   'deaths': '10435',
#   'aadr': '27.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Colorado',
#   'deaths': '2106',
#   'aadr': '43.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Connecticut',
#   'deaths': '1337',
#   'aadr': '33.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Delaware',
#   'deaths': '357',
#   'aadr': '39.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'District of Columbia',
#   'deaths': '212',
#   'aadr': '35.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Florida',
#   'deaths': '8875',
#   'aadr': '43.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Georgia',
#   'deaths': '3745',
#   'aadr': '40.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Hawaii',
#   'deaths': '432',
#   'aadr': '29.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Idaho',
#   'deaths': '654',
#   'aadr': '42.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Illinois',
#   'deaths': '3997',
#   'aadr': '30.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Indiana',
#   'deaths': '2534',
#   'aadr': '38.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Iowa',
#   'deaths': '1273',
#   'aadr': '37.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Kansas',
#   'deaths': '1317',
#   'aadr': '44.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Kentucky',
#   'deaths': '2632',
#   'aadr': '60.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Louisiana',
#   'deaths': '1999',
#   'aadr': '44.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Maine',
#   'deaths': '540',
#   'aadr': '36.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Maryland',
#   'deaths': '1446',
#   'aadr': '24.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Massachusetts',
#   'deaths': '2060',
#   'aadr': '28.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Michigan',
#   'deaths': '3770',
#   'aadr': '36.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Minnesota',
#   'deaths': '2103',
#   'aadr': '36.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Mississippi',
#   'deaths': '1685',
#   'aadr': '56.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Missouri',
#   'deaths': '2975',
#   'aadr': '47.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Montana',
#   'deaths': '548',
#   'aadr': '53.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Nebraska',
#   'deaths': '700',
#   'aadr': '35.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Nevada',
#   'deaths': '1088',
#   'aadr': '41.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Hampshire',
#   'deaths': '517',
#   'aadr': '37.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Jersey',
#   'deaths': '2486',
#   'aadr': '26.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Mexico',
#   'deaths': '1233',
#   'aadr': '60.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New York',
#   'deaths': '5004',
#   'aadr': '24.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'North Carolina',
#   'deaths': '4144',
#   'aadr': '43.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'North Dakota',
#   'deaths': '285',
#   'aadr': '38.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Ohio',
#   'deaths': '5124',
#   'aadr': '42.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Oklahoma',
#   'deaths': '2288',
#   'aadr': '60.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Oregon',
#   'deaths': '1566',
#   'aadr': '37.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Pennsylvania',
#   'deaths': '5751',
#   'aadr': '41.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Rhode Island',
#   'deaths': '475',
#   'aadr': '40.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'South Carolina',
#   'deaths': '2274',
#   'aadr': '48.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'South Dakota',
#   'deaths': '393',
#   'aadr': '44.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Tennessee',
#   'deaths': '3539',
#   'aadr': '54.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Texas',
#   'deaths': '9212',
#   'aadr': '39.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'United States',
#   'deaths': '120859',
#   'aadr': '38.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Utah',
#   'deaths': '970',
#   'aadr': '40.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Vermont',
#   'deaths': '298',
#   'aadr': '42.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Virginia',
#   'deaths': '2527',
#   'aadr': '31.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Washington',
#   'deaths': '2609',
#   'aadr': '37.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'West Virginia',
#   'deaths': '1234',
#   'aadr': '63.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Wisconsin',
#   'deaths': '2525',
#   'aadr': '40.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Wyoming',
#   'deaths': '346',
#   'aadr': '59.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Alabama',
#   'deaths': '48038',
#   'aadr': '939.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Alaska',
#   'deaths': '3728',
#   'aadr': '771.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Arizona',
#   'deaths': '46762',
#   'aadr': '693.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Arkansas',
#   'deaths': '28916',
#   'aadr': '892.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'California',
#   'deaths': '234012',
#   'aadr': '646.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Colorado',
#   'deaths': '31465',
#   'aadr': '682.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Connecticut',
#   'deaths': '28692',
#   'aadr': '652.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Delaware',
#   'deaths': '7706',
#   'aadr': '769.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'District of Columbia',
#   'deaths': '4672',
#   'aadr': '792.4'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Florida',
#   'deaths': '173791',
#   'aadr': '701.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Georgia',
#   'deaths': '71263',
#   'aadr': '845.4'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Hawaii',
#   'deaths': '9617',
#   'aadr': '589.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Idaho',
#   'deaths': '11429',
#   'aadr': '731.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Illinois',
#   'deaths': '99931',
#   'aadr': '736.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Indiana',
#   'deaths': '56743',
#   'aadr': '820.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Iowa',
#   'deaths': '27745',
#   'aadr': '721.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Kansas',
#   'deaths': '24502',
#   'aadr': '762.2'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Kentucky',
#   'deaths': '41983',
#   'aadr': '915.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Louisiana',
#   'deaths': '40667',
#   'aadr': '903.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Maine',
#   'deaths': '12750',
#   'aadr': '749.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Maryland',
#   'deaths': '43325',
#   'aadr': '728.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Massachusetts',
#   'deaths': '52583',
#   'aadr': '675.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Michigan',
#   'deaths': '88021',
#   'aadr': '786.2'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Minnesota',
#   'deaths': '38972',
#   'aadr': '661.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Mississippi',
#   'deaths': '28965',
#   'aadr': '962.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Missouri',
#   'deaths': '55281',
#   'aadr': '819.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Montana',
#   'deaths': '8827',
#   'aadr': '754.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Nebraska',
#   'deaths': '15171',
#   'aadr': '717.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Nevada',
#   'deaths': '19623',
#   'aadr': '795.4'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Hampshire',
#   'deaths': '10201',
#   'aadr': '690.4'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Jersey',
#   'deaths': '69495',
#   'aadr': '691.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Mexico',
#   'deaths': '15931',
#   'aadr': '749.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New York',
#   'deaths': '146432',
#   'aadr': '665.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'North Carolina',
#   'deaths': '78773',
#   'aadr': '804.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'North Dakota',
#   'deaths': '5944',
#   'aadr': '704.3'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Ohio',
#   'deaths': '108711',
#   'aadr': '815.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Oklahoma',
#   'deaths': '36529',
#   'aadr': '915.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Oregon',
#   'deaths': '31890',
#   'aadr': '723.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Pennsylvania',
#   'deaths': '124596',
#   'aadr': '765.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Rhode Island',
#   'deaths': '9579',
#   'aadr': '721.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'South Carolina',
#   'deaths': '41614',
#   'aadr': '854.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'South Dakota',
#   'deaths': '7100',
#   'aadr': '715.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Tennessee',
#   'deaths': '59578',
#   'aadr': '890.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Texas',
#   'deaths': '166527',
#   'aadr': '772.3'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'United States',
#   'deaths': '2468435',
#   'aadr': '747.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Utah',
#   'deaths': '14776',
#   'aadr': '703.2'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Vermont',
#   'deaths': '5380',
#   'aadr': '718.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Virginia',
#   'deaths': '59032',
#   'aadr': '741.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Washington',
#   'deaths': '48146',
#   'aadr': '692.3'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'West Virginia',
#   'deaths': '21275',
#   'aadr': '933.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Wisconsin',
#   'deaths': '47308',
#   'aadr': '719.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Wyoming',
#   'deaths': '4438',
#   'aadr': '778.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Alabama',
#   'deaths': '1523',
#   'aadr': '31.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Alaska',
#   'deaths': '85',
#   'aadr': '25.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Arizona',
#   'deaths': '2327',
#   'aadr': '35.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Arkansas',
#   'deaths': '955',
#   'aadr': '29.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'California',
#   'deaths': '10856',
#   'aadr': '30.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Colorado',
#   'deaths': '1334',
#   'aadr': '31.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Connecticut',
#   'deaths': '820',
#   'aadr': '17.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Delaware',
#   'deaths': '215',
#   'aadr': '21.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'District of Columbia',
#   'deaths': '114',
#   'aadr': '18.7'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Florida',
#   'deaths': '4831',
#   'aadr': '18.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Georgia',
#   'deaths': '2080',
#   'aadr': '28.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Hawaii',
#   'deaths': '189',
#   'aadr': '10.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Idaho',
#   'deaths': '410',
#   'aadr': '26.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Illinois',
#   'deaths': '2927',
#   'aadr': '20.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Indiana',
#   'deaths': '1940',
#   'aadr': '27.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Iowa',
#   'deaths': '1411',
#   'aadr': '32.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Kansas',
#   'deaths': '825',
#   'aadr': '24.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Kentucky',
#   'deaths': '1464',
#   'aadr': '33.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Louisiana',
#   'deaths': '1295',
#   'aadr': '30.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Maine',
#   'deaths': '502',
#   'aadr': '28.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Maryland',
#   'deaths': '986',
#   'aadr': '16.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Massachusetts',
#   'deaths': '1773',
#   'aadr': '21.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Michigan',
#   'deaths': '2736',
#   'aadr': '24.0'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Minnesota',
#   'deaths': '1451',
#   'aadr': '23.4'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Mississippi',
#   'deaths': '927',
#   'aadr': '32.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Missouri',
#   'deaths': '1986',
#   'aadr': '28.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Montana',
#   'deaths': '302',
#   'aadr': '25.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Nebraska',
#   'deaths': '565',
#   'aadr': '24.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Nevada',
#   'deaths': '296',
#   'aadr': '14.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Hampshire',
#   'deaths': '396',
#   'aadr': '26.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Jersey',
#   'deaths': '1878',
#   'aadr': '17.7'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Mexico',
#   'deaths': '343',
#   'aadr': '16.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New York',
#   'deaths': '2616',
#   'aadr': '11.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'North Carolina',
#   'deaths': '2817',
#   'aadr': '30.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'North Dakota',
#   'deaths': '361',
#   'aadr': '37.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Ohio',
#   'deaths': '4109',
#   'aadr': '29.7'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Oklahoma',
#   'deaths': '1015',
#   'aadr': '26.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Oregon',
#   'deaths': '1300',
#   'aadr': '28.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Pennsylvania',
#   'deaths': '3591',
#   'aadr': '20.0'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Rhode Island',
#   'deaths': '338',
#   'aadr': '22.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'South Carolina',
#   'deaths': '1570',
#   'aadr': '34.7'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'South Dakota',
#   'deaths': '398',
#   'aadr': '35.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Tennessee',
#   'deaths': '2440',
#   'aadr': '38.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Texas',
#   'deaths': '5209',
#   'aadr': '26.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'United States',
#   'deaths': '83494',
#   'aadr': '25.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Utah',
#   'deaths': '375',
#   'aadr': '19.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Vermont',
#   'deaths': '238',
#   'aadr': '30.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Virginia',
#   'deaths': '1848',
#   'aadr': '24.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Washington',
#   'deaths': '3025',
#   'aadr': '43.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'West Virginia',
#   'deaths': '594',
#   'aadr': '26.0'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Wisconsin',
#   'deaths': '1762',
#   'aadr': '25.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Wyoming',
#   'deaths': '146',
#   'aadr': '27.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Alabama',
#   'deaths': '2619',
#   'aadr': '51.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Alaska',
#   'deaths': '167',
#   'aadr': '40.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Arizona',
#   'deaths': '2138',
#   'aadr': '31.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Arkansas',
#   'deaths': '1741',
#   'aadr': '53.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'California',
#   'deaths': '13662',
#   'aadr': '38.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Colorado',
#   'deaths': '1607',
#   'aadr': '36.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Connecticut',
#   'deaths': '1349',
#   'aadr': '29.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Delaware',
#   'deaths': '407',
#   'aadr': '40.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'District of Columbia',
#   'deaths': '196',
#   'aadr': '32.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Florida',
#   'deaths': '8432',
#   'aadr': '32.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Georgia',
#   'deaths': '3762',
#   'aadr': '46.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Hawaii',
#   'deaths': '605',
#   'aadr': '35.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Idaho',
#   'deaths': '642',
#   'aadr': '42.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Illinois',
#   'deaths': '5349',
#   'aadr': '39.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Indiana',
#   'deaths': '3082',
#   'aadr': '44.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Iowa',
#   'deaths': '1537',
#   'aadr': '38.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Kansas',
#   'deaths': '1370',
#   'aadr': '41.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Kentucky',
#   'deaths': '1992',
#   'aadr': '44.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Louisiana',
#   'deaths': '1977',
#   'aadr': '44.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Maine',
#   'deaths': '602',
#   'aadr': '34.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Maryland',
#   'deaths': '2279',
#   'aadr': '38.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Massachusetts',
#   'deaths': '2516',
#   'aadr': '31.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Michigan',
#   'deaths': '4474',
#   'aadr': '39.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Minnesota',
#   'deaths': '2167',
#   'aadr': '36.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Mississippi',
#   'deaths': '1520',
#   'aadr': '51.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Missouri',
#   'deaths': '3001',
#   'aadr': '44.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Montana',
#   'deaths': '494',
#   'aadr': '41.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Nebraska',
#   'deaths': '876',
#   'aadr': '40.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Nevada',
#   'deaths': '796',
#   'aadr': '33.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Hampshire',
#   'deaths': '500',
#   'aadr': '33.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Jersey',
#   'deaths': '3402',
#   'aadr': '33.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Mexico',
#   'deaths': '806',
#   'aadr': '38.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New York',
#   'deaths': '6213',
#   'aadr': '27.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'North Carolina',
#   'deaths': '4298',
#   'aadr': '44.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'North Dakota',
#   'deaths': '382',
#   'aadr': '42.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Ohio',
#   'deaths': '5755',
#   'aadr': '42.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Oklahoma',
#   'deaths': '1980',
#   'aadr': '50.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Oregon',
#   'deaths': '1793',
#   'aadr': '40.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Pennsylvania',
#   'deaths': '6701',
#   'aadr': '39.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Rhode Island',
#   'deaths': '431',
#   'aadr': '31.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'South Carolina',
#   'deaths': '2293',
#   'aadr': '47.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'South Dakota',
#   'deaths': '416',
#   'aadr': '39.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Tennessee',
#   'deaths': '3205',
#   'aadr': '48.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Texas',
#   'deaths': '9180',
#   'aadr': '44.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'United States',
#   'deaths': '129476',
#   'aadr': '39.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Utah',
#   'deaths': '739',
#   'aadr': '37.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Vermont',
#   'deaths': '265',
#   'aadr': '35.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Virginia',
#   'deaths': '3293',
#   'aadr': '42.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Washington',
#   'deaths': '2548',
#   'aadr': '37.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'West Virginia',
#   'deaths': '1104',
#   'aadr': '47.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Wisconsin',
#   'deaths': '2609',
#   'aadr': '38.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Wyoming',
#   'deaths': '204',
#   'aadr': '37.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Alabama',
#   'deaths': '2866',
#   'aadr': '55.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Alaska',
#   'deaths': '176',
#   'aadr': '41.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Arizona',
#   'deaths': '2926',
#   'aadr': '43.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Arkansas',
#   'deaths': '1773',
#   'aadr': '53.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'California',
#   'deaths': '12987',
#   'aadr': '37.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Colorado',
#   'deaths': '2199',
#   'aadr': '49.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Connecticut',
#   'deaths': '1289',
#   'aadr': '29.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Delaware',
#   'deaths': '441',
#   'aadr': '44.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'District of Columbia',
#   'deaths': '147',
#   'aadr': '25.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Florida',
#   'deaths': '10337',
#   'aadr': '40.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Georgia',
#   'deaths': '3816',
#   'aadr': '46.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Hawaii',
#   'deaths': '296',
#   'aadr': '18.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Idaho',
#   'deaths': '727',
#   'aadr': '47.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Illinois',
#   'deaths': '5231',
#   'aadr': '39.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Indiana',
#   'deaths': '3794',
#   'aadr': '55.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Iowa',
#   'deaths': '1698',
#   'aadr': '44.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Kansas',
#   'deaths': '1580',
#   'aadr': '50.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Kentucky',
#   'deaths': '2779',
#   'aadr': '60.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Louisiana',
#   'deaths': '1939',
#   'aadr': '43.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Maine',
#   'deaths': '809',
#   'aadr': '47.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Maryland',
#   'deaths': '2039',
#   'aadr': '35.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Massachusetts',
#   'deaths': '2383',
#   'aadr': '31.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Michigan',
#   'deaths': '5079',
#   'aadr': '45.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Minnesota',
#   'deaths': '2016',
#   'aadr': '35.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Mississippi',
#   'deaths': '1661',
#   'aadr': '55.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Missouri',
#   'deaths': '3557',
#   'aadr': '52.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Montana',
#   'deaths': '602',
#   'aadr': '51.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Nebraska',
#   'deaths': '1008',
#   'aadr': '48.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Nevada',
#   'deaths': '1186',
#   'aadr': '49.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Hampshire',
#   'deaths': '609',
#   'aadr': '41.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Jersey',
#   'deaths': '3106',
#   'aadr': '31.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Mexico',
#   'deaths': '1022',
#   'aadr': '47.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New York',
#   'deaths': '6847',
#   'aadr': '31.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'North Carolina',
#   'deaths': '4495',
#   'aadr': '46.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'North Dakota',
#   'deaths': '356',
#   'aadr': '43.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Ohio',
#   'deaths': '6717',
#   'aadr': '50.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Oklahoma',
#   'deaths': '2720',
#   'aadr': '67.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Oregon',
#   'deaths': '1971',
#   'aadr': '45.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Pennsylvania',
#   'deaths': '6202',
#   'aadr': '37.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Rhode Island',
#   'deaths': '507',
#   'aadr': '38.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'South Carolina',
#   'deaths': '2264',
#   'aadr': '46.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'South Dakota',
#   'deaths': '451',
#   'aadr': '46.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Tennessee',
#   'deaths': '3551',
#   'aadr': '52.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Texas',
#   'deaths': '8921',
#   'aadr': '43.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'United States',
#   'deaths': '138080',
#   'aadr': '42.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Utah',
#   'deaths': '671',
#   'aadr': '33.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Vermont',
#   'deaths': '335',
#   'aadr': '45.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Virginia',
#   'deaths': '2969',
#   'aadr': '38.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Washington',
#   'deaths': '2737',
#   'aadr': '40.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'West Virginia',
#   'deaths': '1482',
#   'aadr': '62.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Wisconsin',
#   'deaths': '2474',
#   'aadr': '38.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Wyoming',
#   'deaths': '332',
#   'aadr': '59.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Alabama',
#   'deaths': '1302',
#   'aadr': '25.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Alaska',
#   'deaths': '86',
#   'aadr': '19.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Arizona',
#   'deaths': '1389',
#   'aadr': '20.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Arkansas',
#   'deaths': '850',
#   'aadr': '25.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'California',
#   'deaths': '7061',
#   'aadr': '19.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Colorado',
#   'deaths': '721',
#   'aadr': '15.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Connecticut',
#   'deaths': '662',
#   'aadr': '15.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Delaware',
#   'deaths': '196',
#   'aadr': '19.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'District of Columbia',
#   'deaths': '145',
#   'aadr': '24.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Florida',
#   'deaths': '5024',
#   'aadr': '20.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Georgia',
#   'deaths': '1996',
#   'aadr': '23.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Hawaii',
#   'deaths': '272',
#   'aadr': '16.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Idaho',
#   'deaths': '353',
#   'aadr': '22.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Illinois',
#   'deaths': '2507',
#   'aadr': '18.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Indiana',
#   'deaths': '1587',
#   'aadr': '22.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Iowa',
#   'deaths': '733',
#   'aadr': '19.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Kansas',
#   'deaths': '655',
#   'aadr': '20.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Kentucky',
#   'deaths': '1212',
#   'aadr': '26.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Louisiana',
#   'deaths': '1205',
#   'aadr': '26.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Maine',
#   'deaths': '376',
#   'aadr': '21.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Maryland',
#   'deaths': '1191',
#   'aadr': '19.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Massachusetts',
#   'deaths': '1028',
# ...
#   'cause_name': 'Heart disease',
#   'state': 'Nevada',
#   'deaths': '5043',
#   'aadr': '196.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'New Hampshire',
#   'deaths': '2333',
#   'aadr': '151.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'New Jersey',
#   'deaths': '18330',
#   'aadr': '174.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'New Mexico',
#   'deaths': '3333',
#   'aadr': '150.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'New York',
#   'deaths': '44501',
#   'aadr': '193.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'North Carolina',
#   'deaths': '17003',
#   'aadr': '167.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'North Dakota',
#   'deaths': '1290',
#   'aadr': '144.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Ohio',
#   'deaths': '26298',
#   'aadr': '190.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Oklahoma',
#   'deaths': '9399',
#   'aadr': '228.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Oregon',
#   'deaths': '6255',
#   'aadr': '135.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Pennsylvania',
#   'deaths': '31934',
#   'aadr': '185.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Rhode Island',
#   'deaths': '2390',
#   'aadr': '167.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'South Carolina',
#   'deaths': '9295',
#   'aadr': '184.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'South Dakota',
#   'deaths': '1625',
#   'aadr': '154.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Tennessee',
#   'deaths': '14235',
#   'aadr': '205.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Texas',
#   'deaths': '38094',
#   'aadr': '172.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'United States',
#   'deaths': '596577',
#   'aadr': '173.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Utah',
#   'deaths': '3036',
#   'aadr': '144.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Vermont',
#   'deaths': '1187',
#   'aadr': '151.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Virginia',
#   'deaths': '13272',
#   'aadr': '162.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Washington',
#   'deaths': '10439',
#   'aadr': '143.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'West Virginia',
#   'deaths': '4914',
#   'aadr': '210.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Wisconsin',
#   'deaths': '11266',
#   'aadr': '163.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Wyoming',
#   'deaths': '926',
#   'aadr': '158.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Alabama',
#   'deaths': '951',
#   'aadr': '18.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Alaska',
#   'deaths': '58',
#   'aadr': '12.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Arizona',
#   'deaths': '690',
#   'aadr': '10.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Arkansas',
#   'deaths': '727',
#   'aadr': '21.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'California',
#   'deaths': '6200',
#   'aadr': '16.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Colorado',
#   'deaths': '618',
#   'aadr': '13.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Connecticut',
#   'deaths': '696',
#   'aadr': '14.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Delaware',
#   'deaths': '133',
#   'aadr': '13.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'District of Columbia',
#   'deaths': '96',
#   'aadr': '15.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Florida',
#   'deaths': '2453',
#   'aadr': '9.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Georgia',
#   'deaths': '1457',
#   'aadr': '17.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Hawaii',
#   'deaths': '325',
#   'aadr': '18.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Idaho',
#   'deaths': '217',
#   'aadr': '13.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Illinois',
#   'deaths': '2424',
#   'aadr': '17.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Indiana',
#   'deaths': '1031',
#   'aadr': '14.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Iowa',
#   'deaths': '660',
#   'aadr': '15.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Kansas',
#   'deaths': '647',
#   'aadr': '18.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Kentucky',
#   'deaths': '961',
#   'aadr': '20.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Louisiana',
#   'deaths': '851',
#   'aadr': '18.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Maine',
#   'deaths': '302',
#   'aadr': '16.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Maryland',
#   'deaths': '1036',
#   'aadr': '17.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Massachusetts',
#   'deaths': '1418',
#   'aadr': '16.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Michigan',
#   'deaths': '1750',
#   'aadr': '15.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Minnesota',
#   'deaths': '680',
#   'aadr': '10.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Mississippi',
#   'deaths': '603',
#   'aadr': '20.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Missouri',
#   'deaths': '1205',
#   'aadr': '17.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Montana',
#   'deaths': '156',
#   'aadr': '12.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Nebraska',
#   'deaths': '325',
#   'aadr': '14.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Nevada',
#   'deaths': '499',
#   'aadr': '19.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Hampshire',
#   'deaths': '220',
#   'aadr': '14.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Jersey',
#   'deaths': '1257',
#   'aadr': '12.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Mexico',
#   'deaths': '355',
#   'aadr': '16.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New York',
#   'deaths': '4915',
#   'aadr': '21.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'North Carolina',
#   'deaths': '1619',
#   'aadr': '16.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'North Dakota',
#   'deaths': '120',
#   'aadr': '13.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Ohio',
#   'deaths': '2291',
#   'aadr': '16.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Oklahoma',
#   'deaths': '863',
#   'aadr': '21.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Oregon',
#   'deaths': '401',
#   'aadr': '8.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Pennsylvania',
#   'deaths': '2771',
#   'aadr': '16.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Rhode Island',
#   'deaths': '226',
#   'aadr': '15.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'South Carolina',
#   'deaths': '768',
#   'aadr': '15.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'South Dakota',
#   'deaths': '178',
#   'aadr': '16.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Tennessee',
#   'deaths': '1480',
#   'aadr': '21.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Texas',
#   'deaths': '3055',
#   'aadr': '14.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'United States',
#   'deaths': '53826',
#   'aadr': '15.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Utah',
#   'deaths': '358',
#   'aadr': '17.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Vermont',
#   'deaths': '68',
#   'aadr': '8.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Virginia',
#   'deaths': '1421',
#   'aadr': '17.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Washington',
#   'deaths': '734',
#   'aadr': '10.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'West Virginia',
#   'deaths': '455',
#   'aadr': '19.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Wisconsin',
#   'deaths': '986',
#   'aadr': '14.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Wyoming',
#   'deaths': '116',
#   'aadr': '20.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Alabama',
#   'deaths': '654',
#   'aadr': '13.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Alaska',
#   'deaths': '143',
#   'aadr': '20.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Arizona',
#   'deaths': '1160',
#   'aadr': '17.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Arkansas',
#   'deaths': '462',
#   'aadr': '16.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'California',
#   'deaths': '3996',
#   'aadr': '10.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Colorado',
#   'deaths': '913',
#   'aadr': '17.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Connecticut',
#   'deaths': '370',
#   'aadr': '9.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Delaware',
#   'deaths': '105',
#   'aadr': '11.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'District of Columbia',
#   'deaths': '37',
#   'aadr': '5.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Florida',
#   'deaths': '2880',
#   'aadr': '13.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Georgia',
#   'deaths': '1157',
#   'aadr': '11.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Hawaii',
#   'deaths': '181',
#   'aadr': '12.8'},
#  ...]

# %%
results_df = pd.DataFrame(loaded_json)
results_df.head()
# Out:
#    year                                    _113_cause_name  \
# 0  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2010  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                cause_name       state deaths  aadr
# 0  Unintentional injuries     Alabama   2394  49.6
# 1  Unintentional injuries      Alaska    366  58.7
# 2  Unintentional injuries     Arizona   3018  46.7
# 3  Unintentional injuries    Arkansas   1461  49.4
# 4  Unintentional injuries  California  10435  27.8

# %%
results_df.count()
# Out:
# year               4576
# _113_cause_name    4576
# cause_name         4576
# state              4576
# deaths             4576
# aadr               4576
# dtype: int64

# %%
death_cause=results_df.drop(columns='_113_cause_name')
death_cause
# Out:
#       year              cause_name          state deaths  aadr
# 0     2010  Unintentional injuries        Alabama   2394  49.6
# 1     2010  Unintentional injuries         Alaska    366  58.7
# 2     2010  Unintentional injuries        Arizona   3018  46.7
# 3     2010  Unintentional injuries       Arkansas   1461  49.4
# 4     2010  Unintentional injuries     California  10435  27.8
# ...    ...                     ...            ...    ...   ...
# 4571  2017          Kidney disease       Virginia   1618  16.9
# 4572  2017          Kidney disease     Washington    439   5.3
# 4573  2017          Kidney disease  West Virginia    436  17.1
# 4574  2017          Kidney disease      Wisconsin    922  12.5
# 4575  2017          Kidney disease        Wyoming     63   9.5
#
# [4576 rows x 5 columns]

# %% [markdown]
# # Load data to MongoDB cloud

# %%
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs and establish connection with the cluster in cloud using id and password
conn= 'mongodb+srv://Harmeet:harmeet123@cluster0-v6uxh.mongodb.net/test?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.death_cause_US_db
collection = db.death_cause

# %%
#Add data to the database in cluster
db.collection.insert_many(death_cause.to_dict('records'))

# %%
#Read data from cluster
records=db.collection.find()
for record in records:
    print(record)
# Out:
# {'_id': ObjectId('5df3cac263ebbde9a082751c'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2394', 'aadr': '49.6'}
# {'_id': ObjectId('5df3cac263ebbde9a082751d'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '366', 'aadr': '58.7'}
# {'_id': ObjectId('5df3cac263ebbde9a082751e'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Arizona', 'deaths': '3018', 'aadr': '46.7'}
# {'_id': ObjectId('5df3cac263ebbde9a082751f'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Arkansas', 'deaths': '1461', 'aadr': '49.4'}
# {'_id': ObjectId('5df3cac263ebbde9a0827520'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'California', 'deaths': '10435', 'aadr': '27.8'}
# {'_id': ObjectId('5df3cac263ebbde9a0827521'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Colorado', 'deaths': '2106', 'aadr': '43.5'}
# {'_id': ObjectId('5df3cac263ebbde9a0827522'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Connecticut', 'deaths': '1337', 'aadr': '33.6'}
# {'_id': ObjectId('5df3cac263ebbde9a0827523'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Delaware', 'deaths': '357', 'aadr': '39.2'}
# {'_id': ObjectId('5df3cac263ebbde9a0827524'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'District of Columbia', 'deaths': '212', 'aadr': '35.1'}
# {'_id': ObjectId('5df3cac263ebbde9a0827525'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': '
8'}
# {'_id': ObjectId('5df3cac263ebbde9a0827644'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Oklahoma', 'deaths': '1089', 'aadr': '26.9'}
# {'_id': ObjectId('5df3cac263ebbde9a0827645'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Oregon', 'deaths': '1052', 'aadr': '23.7'}
# {'_id': ObjectId('5df3cac263ebbde9a0827646'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Pennsylvania', 'deaths': '3242', 'aadr': '20.0'}
# {'_id': ObjectId('5df3cac263ebbde9a0827647'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Rhode Island', 'deaths': '211', 'aadr': '16.0'}
# {'_id': ObjectId('5df3cac263ebbde9a0827648'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'South Carolina', 'deaths': '1128', 'aadr': '22.6'}
# {'_id': ObjectId('5df3cac263ebbde9a0827649'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'South Dakota', 'deaths': '240', 'aadr': '24.5'}
# {'_id': ObjectId('5df3cac263ebbde9a082764a'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Tennessee', 'deaths': '1687', 'aadr': '24.7'}
# {'_id': ObjectId('5df3cac263ebbde9a082764b'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Texas', 'deaths': '4744', 'aadr': '21.6'}
# {'_id': ObjectId('5df3cac263ebbde9a082764c'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'United States', 'deaths': '69071', 'aadr': '20.8'}
# {'_id': ObjectId('5df3cac263ebbde9a082764d'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Utah', 'deaths': '471', 'aadr': '22.7'}
# {'_id': ObjectId('5df3cac263ebbde9a082764e'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Vermont', 'deaths': '151', 'aadr': '20.7'}
# {'_id': ObjectId('5df3cac263ebbde9a082764f'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Virginia', 'deaths': '1530', 'aadr': '18.8'}
# {'_id': ObjectId('5df3cac263ebbde9a0827650'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Washington', 'deaths': '1499', 'aadr': '21.6'}
# {'_id': ObjectId('5df3cac263ebbde9a0827651'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'West Virginia', 'deaths': '776', 'aadr': '32.9'}
# {'_id': ObjectId('5df3cac263ebbde9a0827652'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Wisconsin', 'deaths': '1158', 'aadr': '17.7'}
# {'_id': ObjectId('5df3cac263ebbde9a0827653'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Wyoming', 'deaths': '105', 'aadr': '18.5'}
# {'_id': ObjectId('5df3cac263ebbde9a0827654'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '12083', 'aadr': '236.0'}
# {'_id': ObjectId('5df3cac263ebbde9a0827655'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '707', 'aadr': '151.5'}
# {'_id': ObjectId('5df3cac263ebbde9a0827656'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Arizona', 'deaths': '9954', 'aadr': '146.7'}
# {'_id': ObjectId('5df3cac263ebbde9a0827657'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Arkansas', 'deaths': '7274', 'aadr': '222.5'}
# {'_id': ObjectId('5df3cac263ebbde9a0827658'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'California', 'deaths': '58641', 'aadr': '161.9'}
# {'_id': ObjectId('5df3cac263ebbde9a0827659'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Colorado', 'deaths': '6038', 'aadr': '132.8'}
# {'_id': ObjectId('5df3cac263ebbde9a082765a'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Connecticut', 'deaths': '7127', 'aadr': '155.7'}
# {'_id': ObjectId('5df3cac263ebbde9a082765b'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Delaware', 'deaths': '1776', 'aadr': '175.7'}
# {'_id': ObjectId('5df3cac263ebbde9a082765c'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'District of Columbia', 'deaths': '1306', 'aadr': '222.4'}
# {'_id': ObjectId('5df3cac263ebbde9a082765d'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Florida', 'deaths': '41737', 'aadr': '162.3'}
# {'_id': ObjectId('5df3cac263ebbde9a082765e'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Georgia', 'deaths': '15987', 'aadr': '192.6'}
# {'_id': ObjectId('5df3cac263ebbde9a082765f'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Hawaii', 'deaths': '2239', 'aadr': '134.7'}
# {'_id': ObjectId('5df3cac263ebbde9a0827660'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Idaho', 'deaths': '2495', 'aadr': '159.3'}
# ...
# {'_id': ObjectId('5df3cac263ebbde9a082868f'), 'year': '2017', 'cause_name': 'Suicide', 'state': 'Virginia', 'deaths': '1179', 'aadr': '13.4'}
# {'_id': ObjectId('5df3cac263ebbde9a0828690'), 'year': '2017', 'cause_name': 'Suicide', 'state': 'Washington', 'deaths': '1297', 'aadr': '16.9'}
# {'_id': ObjectId('5df3cac263ebbde9a0828691'), 'year': '2017', 'cause_name': 'Suicide', 'state': 'West Virginia', 'deaths': '393', 'aadr': '21.1'}
# {'_id': ObjectId('5df3cac263ebbde9a0828692'), 'year': '2017', 'cause_name': 'Suicide', 'state': 'Wisconsin', 'deaths': '926', 'aadr': '15.4'}
# {'_id': ObjectId('5df3cac263ebbde9a0828693'), 'year': '2017', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '157', 'aadr': '26.9'}
# {'_id': ObjectId('5df3cac263ebbde9a0828694'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'United States', 'deaths': '599108', 'aadr': '152.5'}
# {'_id': ObjectId('5df3cac263ebbde9a0828695'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10410', 'aadr': '170.0'}
# {'_id': ObjectId('5df3cac263ebbde9a0828696'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '926', 'aadr': '139.2'}
# {'_id': ObjectId('5df3cac263ebbde9a0828697'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'Arizona', 'deaths': '12008', 'aadr': '135.8'}
# {'_id': ObjectId('5df3cac263ebbde9a0828698'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'Arkansas', 'deaths': '6517', 'aadr': '173.6'}
# {'_id': ObjectId('5df3cac263ebbde9a0828699'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'California', 'deaths': '59516', 'aadr': '136.8'}
# {'_id': ObjectId('5df3cac263ebbde9a082869a'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'Colorado', 'deaths': '7829', 'aadr': '131.0'}
# {'_id': ObjectId('5df3cac263ebbde9a082869b'), 'year': '2017', 'cause_name': 'Cancer', 'state': '