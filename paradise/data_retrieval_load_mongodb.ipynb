# %% [markdown]
# # Data retrieval through API

# %% [markdown]
# Based on NCHS - Leading Causes of Death: United States:
# This dataset presents the age-adjusted death rates for the 10 leading causes of death in the United States beginning in 1999.Total number of records are 10,886. For the project, records from 2010 through 2017 have been included reducing the sample size to 4576 records by applying filtering ang paging criteria to the endpoint.
# Data are based on information from all resident death certificates filed in the 50 states and the District of Columbia using demographic and medical characteristics. Age-adjusted death rates (per 100,000 population) are based on the 2000 U.S. standard population. Populations used for computing death rates after 2010 are postcensal estimates based on the 2010 census, estimated as of July 1, 2010. Rates for census years are based on populations enumerated in the corresponding censuses. Rates for non-census years before 2010 are revised using updated intercensal population estimates and may differ from rates previously published.
# Causes of death classified by the International Classification of Diseases, Tenth Revision (ICD–10) are ranked according to the number of deaths assigned to rankable causes. Cause of death statistics are based on the underlying cause of death.

# %%
import os
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup
#from sodapy import Socrata

# %%
url = "https://data.cdc.gov/resource/bi63-dtpu.json?$where=year>=2010&$limit=4600"

# %%
loaded_json = requests.get(url).json()
loaded_json
# Out:
# [{'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Alabama',
#   'deaths': '2394',
#   'aadr': '49.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Alaska',
#   'deaths': '366',
#   'aadr': '58.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Arizona',
#   'deaths': '3018',
#   'aadr': '46.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Arkansas',
#   'deaths': '1461',
#   'aadr': '49.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'California',
#   'deaths': '10435',
#   'aadr': '27.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Colorado',
#   'deaths': '2106',
#   'aadr': '43.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Connecticut',
#   'deaths': '1337',
#   'aadr': '33.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Delaware',
#   'deaths': '357',
#   'aadr': '39.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'District of Columbia',
#   'deaths': '212',
#   'aadr': '35.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Florida',
#   'deaths': '8875',
#   'aadr': '43.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Georgia',
#   'deaths': '3745',
#   'aadr': '40.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Hawaii',
#   'deaths': '432',
#   'aadr': '29.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Idaho',
#   'deaths': '654',
#   'aadr': '42.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Illinois',
#   'deaths': '3997',
#   'aadr': '30.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Indiana',
#   'deaths': '2534',
#   'aadr': '38.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Iowa',
#   'deaths': '1273',
#   'aadr': '37.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Kansas',
#   'deaths': '1317',
#   'aadr': '44.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Kentucky',
#   'deaths': '2632',
#   'aadr': '60.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Louisiana',
#   'deaths': '1999',
#   'aadr': '44.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Maine',
#   'deaths': '540',
#   'aadr': '36.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Maryland',
#   'deaths': '1446',
#   'aadr': '24.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Massachusetts',
#   'deaths': '2060',
#   'aadr': '28.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Michigan',
#   'deaths': '3770',
#   'aadr': '36.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Minnesota',
#   'deaths': '2103',
#   'aadr': '36.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Mississippi',
#   'deaths': '1685',
#   'aadr': '56.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Missouri',
#   'deaths': '2975',
#   'aadr': '47.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Montana',
#   'deaths': '548',
#   'aadr': '53.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Nebraska',
#   'deaths': '700',
#   'aadr': '35.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Nevada',
#   'deaths': '1088',
#   'aadr': '41.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Hampshire',
#   'deaths': '517',
#   'aadr': '37.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Jersey',
#   'deaths': '2486',
#   'aadr': '26.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Mexico',
#   'deaths': '1233',
#   'aadr': '60.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New York',
#   'deaths': '5004',
#   'aadr': '24.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'North Carolina',
#   'deaths': '4144',
#   'aadr': '43.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'North Dakota',
#   'deaths': '285',
#   'aadr': '38.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Ohio',
#   'deaths': '5124',
#   'aadr': '42.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Oklahoma',
#   'deaths': '2288',
#   'aadr': '60.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Oregon',
#   'deaths': '1566',
#   'aadr': '37.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Pennsylvania',
#   'deaths': '5751',
#   'aadr': '41.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Rhode Island',
#   'deaths': '475',
#   'aadr': '40.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'South Carolina',
#   'deaths': '2274',
#   'aadr': '48.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'South Dakota',
#   'deaths': '393',
#   'aadr': '44.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Tennessee',
#   'deaths': '3539',
#   'aadr': '54.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Texas',
#   'deaths': '9212',
#   'aadr': '39.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'United States',
#   'deaths': '120859',
#   'aadr': '38.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Utah',
#   'deaths': '970',
#   'aadr': '40.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Vermont',
#   'deaths': '298',
#   'aadr': '42.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Virginia',
#   'deaths': '2527',
#   'aadr': '31.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Washington',
#   'deaths': '2609',
#   'aadr': '37.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'West Virginia',
#   'deaths': '1234',
#   'aadr': '63.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Wisconsin',
#   'deaths': '2525',
#   'aadr': '40.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Wyoming',
#   'deaths': '346',
#   'aadr': '59.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Alabama',
#   'deaths': '48038',
#   'aadr': '939.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Alaska',
#   'deaths': '3728',
#   'aadr': '771.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Arizona',
#   'deaths': '46762',
#   'aadr': '693.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Arkansas',
#   'deaths': '28916',
#   'aadr': '892.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'California',
#   'deaths': '234012',
#   'aadr': '646.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Colorado',
#   'deaths': '31465',
#   'aadr': '682.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Connecticut',
#   'deaths': '28692',
#   'aadr': '652.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Delaware',
#   'deaths': '7706',
#   'aadr': '769.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'District of Columbia',
#   'deaths': '4672',
#   'aadr': '792.4'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Florida',
#   'deaths': '173791',
#   'aadr': '701.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Georgia',
#   'deaths': '71263',
#   'aadr': '845.4'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Hawaii',
#   'deaths': '9617',
#   'aadr': '589.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Idaho',
#   'deaths': '11429',
#   'aadr': '731.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Illinois',
#   'deaths': '99931',
#   'aadr': '736.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Indiana',
#   'deaths': '56743',
#   'aadr': '820.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Iowa',
#   'deaths': '27745',
#   'aadr': '721.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Kansas',
#   'deaths': '24502',
#   'aadr': '762.2'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Kentucky',
#   'deaths': '41983',
#   'aadr': '915.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Louisiana',
#   'deaths': '40667',
#   'aadr': '903.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Maine',
#   'deaths': '12750',
#   'aadr': '749.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Maryland',
#   'deaths': '43325',
#   'aadr': '728.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Massachusetts',
#   'deaths': '52583',
#   'aadr': '675.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Michigan',
#   'deaths': '88021',
#   'aadr': '786.2'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Minnesota',
#   'deaths': '38972',
#   'aadr': '661.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Mississippi',
#   'deaths': '28965',
#   'aadr': '962.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Missouri',
#   'deaths': '55281',
#   'aadr': '819.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Montana',
#   'deaths': '8827',
#   'aadr': '754.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Nebraska',
#   'deaths': '15171',
#   'aadr': '717.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Nevada',
#   'deaths': '19623',
#   'aadr': '795.4'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Hampshire',
#   'deaths': '10201',
#   'aadr': '690.4'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Jersey',
#   'deaths': '69495',
#   'aadr': '691.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Mexico',
#   'deaths': '15931',
#   'aadr': '749.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New York',
#   'deaths': '146432',
#   'aadr': '665.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'North Carolina',
#   'deaths': '78773',
#   'aadr': '804.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'North Dakota',
#   'deaths': '5944',
#   'aadr': '704.3'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Ohio',
#   'deaths': '108711',
#   'aadr': '815.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Oklahoma',
#   'deaths': '36529',
#   'aadr': '915.5'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Oregon',
#   'deaths': '31890',
#   'aadr': '723.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Pennsylvania',
#   'deaths': '124596',
#   'aadr': '765.9'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Rhode Island',
#   'deaths': '9579',
#   'aadr': '721.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'South Carolina',
#   'deaths': '41614',
#   'aadr': '854.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'South Dakota',
#   'deaths': '7100',
#   'aadr': '715.1'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Tennessee',
#   'deaths': '59578',
#   'aadr': '890.8'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Texas',
#   'deaths': '166527',
#   'aadr': '772.3'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'United States',
#   'deaths': '2468435',
#   'aadr': '747.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Utah',
#   'deaths': '14776',
#   'aadr': '703.2'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Vermont',
#   'deaths': '5380',
#   'aadr': '718.7'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Virginia',
#   'deaths': '59032',
#   'aadr': '741.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Washington',
#   'deaths': '48146',
#   'aadr': '692.3'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'West Virginia',
#   'deaths': '21275',
#   'aadr': '933.6'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Wisconsin',
#   'deaths': '47308',
#   'aadr': '719.0'},
#  {'year': '2010',
#   '_113_cause_name': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Wyoming',
#   'deaths': '4438',
#   'aadr': '778.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Alabama',
#   'deaths': '1523',
#   'aadr': '31.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Alaska',
#   'deaths': '85',
#   'aadr': '25.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Arizona',
#   'deaths': '2327',
#   'aadr': '35.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Arkansas',
#   'deaths': '955',
#   'aadr': '29.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'California',
#   'deaths': '10856',
#   'aadr': '30.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Colorado',
#   'deaths': '1334',
#   'aadr': '31.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Connecticut',
#   'deaths': '820',
#   'aadr': '17.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Delaware',
#   'deaths': '215',
#   'aadr': '21.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'District of Columbia',
#   'deaths': '114',
#   'aadr': '18.7'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Florida',
#   'deaths': '4831',
#   'aadr': '18.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Georgia',
#   'deaths': '2080',
#   'aadr': '28.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Hawaii',
#   'deaths': '189',
#   'aadr': '10.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Idaho',
#   'deaths': '410',
#   'aadr': '26.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Illinois',
#   'deaths': '2927',
#   'aadr': '20.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Indiana',
#   'deaths': '1940',
#   'aadr': '27.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Iowa',
#   'deaths': '1411',
#   'aadr': '32.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Kansas',
#   'deaths': '825',
#   'aadr': '24.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Kentucky',
#   'deaths': '1464',
#   'aadr': '33.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Louisiana',
#   'deaths': '1295',
#   'aadr': '30.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Maine',
#   'deaths': '502',
#   'aadr': '28.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Maryland',
#   'deaths': '986',
#   'aadr': '16.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Massachusetts',
#   'deaths': '1773',
#   'aadr': '21.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Michigan',
#   'deaths': '2736',
#   'aadr': '24.0'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Minnesota',
#   'deaths': '1451',
#   'aadr': '23.4'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Mississippi',
#   'deaths': '927',
#   'aadr': '32.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Missouri',
#   'deaths': '1986',
#   'aadr': '28.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Montana',
#   'deaths': '302',
#   'aadr': '25.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Nebraska',
#   'deaths': '565',
#   'aadr': '24.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Nevada',
#   'deaths': '296',
#   'aadr': '14.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Hampshire',
#   'deaths': '396',
#   'aadr': '26.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Jersey',
#   'deaths': '1878',
#   'aadr': '17.7'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Mexico',
#   'deaths': '343',
#   'aadr': '16.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New York',
#   'deaths': '2616',
#   'aadr': '11.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'North Carolina',
#   'deaths': '2817',
#   'aadr': '30.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'North Dakota',
#   'deaths': '361',
#   'aadr': '37.2'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Ohio',
#   'deaths': '4109',
#   'aadr': '29.7'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Oklahoma',
#   'deaths': '1015',
#   'aadr': '26.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Oregon',
#   'deaths': '1300',
#   'aadr': '28.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Pennsylvania',
#   'deaths': '3591',
#   'aadr': '20.0'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Rhode Island',
#   'deaths': '338',
#   'aadr': '22.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'South Carolina',
#   'deaths': '1570',
#   'aadr': '34.7'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'South Dakota',
#   'deaths': '398',
#   'aadr': '35.9'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Tennessee',
#   'deaths': '2440',
#   'aadr': '38.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Texas',
#   'deaths': '5209',
#   'aadr': '26.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'United States',
#   'deaths': '83494',
#   'aadr': '25.1'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Utah',
#   'deaths': '375',
#   'aadr': '19.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Vermont',
#   'deaths': '238',
#   'aadr': '30.8'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Virginia',
#   'deaths': '1848',
#   'aadr': '24.5'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Washington',
#   'deaths': '3025',
#   'aadr': '43.6'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'West Virginia',
#   'deaths': '594',
#   'aadr': '26.0'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Wisconsin',
#   'deaths': '1762',
#   'aadr': '25.3'},
#  {'year': '2010',
#   '_113_cause_name': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Wyoming',
#   'deaths': '146',
#   'aadr': '27.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Alabama',
#   'deaths': '2619',
#   'aadr': '51.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Alaska',
#   'deaths': '167',
#   'aadr': '40.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Arizona',
#   'deaths': '2138',
#   'aadr': '31.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Arkansas',
#   'deaths': '1741',
#   'aadr': '53.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'California',
#   'deaths': '13662',
#   'aadr': '38.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Colorado',
#   'deaths': '1607',
#   'aadr': '36.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Connecticut',
#   'deaths': '1349',
#   'aadr': '29.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Delaware',
#   'deaths': '407',
#   'aadr': '40.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'District of Columbia',
#   'deaths': '196',
#   'aadr': '32.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Florida',
#   'deaths': '8432',
#   'aadr': '32.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Georgia',
#   'deaths': '3762',
#   'aadr': '46.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Hawaii',
#   'deaths': '605',
#   'aadr': '35.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Idaho',
#   'deaths': '642',
#   'aadr': '42.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Illinois',
#   'deaths': '5349',
#   'aadr': '39.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Indiana',
#   'deaths': '3082',
#   'aadr': '44.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Iowa',
#   'deaths': '1537',
#   'aadr': '38.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Kansas',
#   'deaths': '1370',
#   'aadr': '41.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Kentucky',
#   'deaths': '1992',
#   'aadr': '44.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Louisiana',
#   'deaths': '1977',
#   'aadr': '44.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Maine',
#   'deaths': '602',
#   'aadr': '34.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Maryland',
#   'deaths': '2279',
#   'aadr': '38.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Massachusetts',
#   'deaths': '2516',
#   'aadr': '31.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Michigan',
#   'deaths': '4474',
#   'aadr': '39.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Minnesota',
#   'deaths': '2167',
#   'aadr': '36.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Mississippi',
#   'deaths': '1520',
#   'aadr': '51.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Missouri',
#   'deaths': '3001',
#   'aadr': '44.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Montana',
#   'deaths': '494',
#   'aadr': '41.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Nebraska',
#   'deaths': '876',
#   'aadr': '40.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Nevada',
#   'deaths': '796',
#   'aadr': '33.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Hampshire',
#   'deaths': '500',
#   'aadr': '33.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Jersey',
#   'deaths': '3402',
#   'aadr': '33.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Mexico',
#   'deaths': '806',
#   'aadr': '38.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New York',
#   'deaths': '6213',
#   'aadr': '27.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'North Carolina',
#   'deaths': '4298',
#   'aadr': '44.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'North Dakota',
#   'deaths': '382',
#   'aadr': '42.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Ohio',
#   'deaths': '5755',
#   'aadr': '42.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Oklahoma',
#   'deaths': '1980',
#   'aadr': '50.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Oregon',
#   'deaths': '1793',
#   'aadr': '40.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Pennsylvania',
#   'deaths': '6701',
#   'aadr': '39.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Rhode Island',
#   'deaths': '431',
#   'aadr': '31.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'South Carolina',
#   'deaths': '2293',
#   'aadr': '47.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'South Dakota',
#   'deaths': '416',
#   'aadr': '39.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Tennessee',
#   'deaths': '3205',
#   'aadr': '48.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Texas',
#   'deaths': '9180',
#   'aadr': '44.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'United States',
#   'deaths': '129476',
#   'aadr': '39.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Utah',
#   'deaths': '739',
#   'aadr': '37.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Vermont',
#   'deaths': '265',
#   'aadr': '35.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Virginia',
#   'deaths': '3293',
#   'aadr': '42.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Washington',
#   'deaths': '2548',
#   'aadr': '37.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'West Virginia',
#   'deaths': '1104',
#   'aadr': '47.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Wisconsin',
#   'deaths': '2609',
#   'aadr': '38.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Wyoming',
#   'deaths': '204',
#   'aadr': '37.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Alabama',
#   'deaths': '2866',
#   'aadr': '55.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Alaska',
#   'deaths': '176',
#   'aadr': '41.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Arizona',
#   'deaths': '2926',
#   'aadr': '43.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Arkansas',
#   'deaths': '1773',
#   'aadr': '53.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'California',
#   'deaths': '12987',
#   'aadr': '37.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Colorado',
#   'deaths': '2199',
#   'aadr': '49.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Connecticut',
#   'deaths': '1289',
#   'aadr': '29.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Delaware',
#   'deaths': '441',
#   'aadr': '44.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'District of Columbia',
#   'deaths': '147',
#   'aadr': '25.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Florida',
#   'deaths': '10337',
#   'aadr': '40.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Georgia',
#   'deaths': '3816',
#   'aadr': '46.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Hawaii',
#   'deaths': '296',
#   'aadr': '18.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Idaho',
#   'deaths': '727',
#   'aadr': '47.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Illinois',
#   'deaths': '5231',
#   'aadr': '39.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Indiana',
#   'deaths': '3794',
#   'aadr': '55.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Iowa',
#   'deaths': '1698',
#   'aadr': '44.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Kansas',
#   'deaths': '1580',
#   'aadr': '50.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Kentucky',
#   'deaths': '2779',
#   'aadr': '60.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Louisiana',
#   'deaths': '1939',
#   'aadr': '43.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Maine',
#   'deaths': '809',
#   'aadr': '47.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Maryland',
#   'deaths': '2039',
#   'aadr': '35.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Massachusetts',
#   'deaths': '2383',
#   'aadr': '31.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Michigan',
#   'deaths': '5079',
#   'aadr': '45.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Minnesota',
#   'deaths': '2016',
#   'aadr': '35.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Mississippi',
#   'deaths': '1661',
#   'aadr': '55.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Missouri',
#   'deaths': '3557',
#   'aadr': '52.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Montana',
#   'deaths': '602',
#   'aadr': '51.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Nebraska',
#   'deaths': '1008',
#   'aadr': '48.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Nevada',
#   'deaths': '1186',
#   'aadr': '49.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Hampshire',
#   'deaths': '609',
#   'aadr': '41.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Jersey',
#   'deaths': '3106',
#   'aadr': '31.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Mexico',
#   'deaths': '1022',
#   'aadr': '47.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New York',
#   'deaths': '6847',
#   'aadr': '31.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'North Carolina',
#   'deaths': '4495',
#   'aadr': '46.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'North Dakota',
#   'deaths': '356',
#   'aadr': '43.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Ohio',
#   'deaths': '6717',
#   'aadr': '50.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Oklahoma',
#   'deaths': '2720',
#   'aadr': '67.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Oregon',
#   'deaths': '1971',
#   'aadr': '45.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Pennsylvania',
#   'deaths': '6202',
#   'aadr': '37.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Rhode Island',
#   'deaths': '507',
#   'aadr': '38.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'South Carolina',
#   'deaths': '2264',
#   'aadr': '46.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'South Dakota',
#   'deaths': '451',
#   'aadr': '46.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Tennessee',
#   'deaths': '3551',
#   'aadr': '52.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Texas',
#   'deaths': '8921',
#   'aadr': '43.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'United States',
#   'deaths': '138080',
#   'aadr': '42.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Utah',
#   'deaths': '671',
#   'aadr': '33.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Vermont',
#   'deaths': '335',
#   'aadr': '45.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Virginia',
#   'deaths': '2969',
#   'aadr': '38.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Washington',
#   'deaths': '2737',
#   'aadr': '40.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'West Virginia',
#   'deaths': '1482',
#   'aadr': '62.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Wisconsin',
#   'deaths': '2474',
#   'aadr': '38.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Wyoming',
#   'deaths': '332',
#   'aadr': '59.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Alabama',
#   'deaths': '1302',
#   'aadr': '25.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Alaska',
#   'deaths': '86',
#   'aadr': '19.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Arizona',
#   'deaths': '1389',
#   'aadr': '20.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Arkansas',
#   'deaths': '850',
#   'aadr': '25.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'California',
#   'deaths': '7061',
#   'aadr': '19.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Colorado',
#   'deaths': '721',
#   'aadr': '15.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Connecticut',
#   'deaths': '662',
#   'aadr': '15.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Delaware',
#   'deaths': '196',
#   'aadr': '19.2'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'District of Columbia',
#   'deaths': '145',
#   'aadr': '24.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Florida',
#   'deaths': '5024',
#   'aadr': '20.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Georgia',
#   'deaths': '1996',
#   'aadr': '23.1'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Hawaii',
#   'deaths': '272',
#   'aadr': '16.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Idaho',
#   'deaths': '353',
#   'aadr': '22.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Illinois',
#   'deaths': '2507',
#   'aadr': '18.5'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Indiana',
#   'deaths': '1587',
#   'aadr': '22.7'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Iowa',
#   'deaths': '733',
#   'aadr': '19.3'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Kansas',
#   'deaths': '655',
#   'aadr': '20.6'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Kentucky',
#   'deaths': '1212',
#   'aadr': '26.0'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Louisiana',
#   'deaths': '1205',
#   'aadr': '26.4'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Maine',
#   'deaths': '376',
#   'aadr': '21.8'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Maryland',
#   'deaths': '1191',
#   'aadr': '19.9'},
#  {'year': '2010',
#   '_113_cause_name': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Massachusetts',
#   'deaths': '1028',
# ...
#   'cause_name': 'Heart disease',
#   'state': 'Nevada',
#   'deaths': '5043',
#   'aadr': '196.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'New Hampshire',
#   'deaths': '2333',
#   'aadr': '151.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'New Jersey',
#   'deaths': '18330',
#   'aadr': '174.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'New Mexico',
#   'deaths': '3333',
#   'aadr': '150.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'New York',
#   'deaths': '44501',
#   'aadr': '193.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'North Carolina',
#   'deaths': '17003',
#   'aadr': '167.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'North Dakota',
#   'deaths': '1290',
#   'aadr': '144.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Ohio',
#   'deaths': '26298',
#   'aadr': '190.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Oklahoma',
#   'deaths': '9399',
#   'aadr': '228.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Oregon',
#   'deaths': '6255',
#   'aadr': '135.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Pennsylvania',
#   'deaths': '31934',
#   'aadr': '185.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Rhode Island',
#   'deaths': '2390',
#   'aadr': '167.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'South Carolina',
#   'deaths': '9295',
#   'aadr': '184.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'South Dakota',
#   'deaths': '1625',
#   'aadr': '154.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Tennessee',
#   'deaths': '14235',
#   'aadr': '205.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Texas',
#   'deaths': '38094',
#   'aadr': '172.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'United States',
#   'deaths': '596577',
#   'aadr': '173.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Utah',
#   'deaths': '3036',
#   'aadr': '144.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Vermont',
#   'deaths': '1187',
#   'aadr': '151.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Virginia',
#   'deaths': '13272',
#   'aadr': '162.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Washington',
#   'deaths': '10439',
#   'aadr': '143.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'West Virginia',
#   'deaths': '4914',
#   'aadr': '210.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Wisconsin',
#   'deaths': '11266',
#   'aadr': '163.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Wyoming',
#   'deaths': '926',
#   'aadr': '158.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Alabama',
#   'deaths': '951',
#   'aadr': '18.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Alaska',
#   'deaths': '58',
#   'aadr': '12.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Arizona',
#   'deaths': '690',
#   'aadr': '10.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Arkansas',
#   'deaths': '727',
#   'aadr': '21.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'California',
#   'deaths': '6200',
#   'aadr': '16.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Colorado',
#   'deaths': '618',
#   'aadr': '13.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Connecticut',
#   'deaths': '696',
#   'aadr': '14.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Delaware',
#   'deaths': '133',
#   'aadr': '13.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'District of Columbia',
#   'deaths': '96',
#   'aadr': '15.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Florida',
#   'deaths': '2453',
#   'aadr': '9.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Georgia',
#   'deaths': '1457',
#   'aadr': '17.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Hawaii',
#   'deaths': '325',
#   'aadr': '18.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Idaho',
#   'deaths': '217',
#   'aadr': '13.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Illinois',
#   'deaths': '2424',
#   'aadr': '17.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Indiana',
#   'deaths': '1031',
#   'aadr': '14.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Iowa',
#   'deaths': '660',
#   'aadr': '15.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Kansas',
#   'deaths': '647',
#   'aadr': '18.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Kentucky',
#   'deaths': '961',
#   'aadr': '20.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Louisiana',
#   'deaths': '851',
#   'aadr': '18.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Maine',
#   'deaths': '302',
#   'aadr': '16.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Maryland',
#   'deaths': '1036',
#   'aadr': '17.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Massachusetts',
#   'deaths': '1418',
#   'aadr': '16.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Michigan',
#   'deaths': '1750',
#   'aadr': '15.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Minnesota',
#   'deaths': '680',
#   'aadr': '10.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Mississippi',
#   'deaths': '603',
#   'aadr': '20.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Missouri',
#   'deaths': '1205',
#   'aadr': '17.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Montana',
#   'deaths': '156',
#   'aadr': '12.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Nebraska',
#   'deaths': '325',
#   'aadr': '14.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Nevada',
#   'deaths': '499',
#   'aadr': '19.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Hampshire',
#   'deaths': '220',
#   'aadr': '14.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Jersey',
#   'deaths': '1257',
#   'aadr': '12.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Mexico',
#   'deaths': '355',
#   'aadr': '16.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New York',
#   'deaths': '4915',
#   'aadr': '21.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'North Carolina',
#   'deaths': '1619',
#   'aadr': '16.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'North Dakota',
#   'deaths': '120',
#   'aadr': '13.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Ohio',
#   'deaths': '2291',
#   'aadr': '16.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Oklahoma',
#   'deaths': '863',
#   'aadr': '21.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Oregon',
#   'deaths': '401',
#   'aadr': '8.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Pennsylvania',
#   'deaths': '2771',
#   'aadr': '16.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Rhode Island',
#   'deaths': '226',
#   'aadr': '15.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'South Carolina',
#   'deaths': '768',
#   'aadr': '15.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'South Dakota',
#   'deaths': '178',
#   'aadr': '16.3'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Tennessee',
#   'deaths': '1480',
#   'aadr': '21.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Texas',
#   'deaths': '3055',
#   'aadr': '14.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'United States',
#   'deaths': '53826',
#   'aadr': '15.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Utah',
#   'deaths': '358',
#   'aadr': '17.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Vermont',
#   'deaths': '68',
#   'aadr': '8.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Virginia',
#   'deaths': '1421',
#   'aadr': '17.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Washington',
#   'deaths': '734',
#   'aadr': '10.1'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'West Virginia',
#   'deaths': '455',
#   'aadr': '19.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Wisconsin',
#   'deaths': '986',
#   'aadr': '14.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Wyoming',
#   'deaths': '116',
#   'aadr': '20.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Alabama',
#   'deaths': '654',
#   'aadr': '13.2'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Alaska',
#   'deaths': '143',
#   'aadr': '20.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Arizona',
#   'deaths': '1160',
#   'aadr': '17.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Arkansas',
#   'deaths': '462',
#   'aadr': '16.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'California',
#   'deaths': '3996',
#   'aadr': '10.4'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Colorado',
#   'deaths': '913',
#   'aadr': '17.5'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Connecticut',
#   'deaths': '370',
#   'aadr': '9.8'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Delaware',
#   'deaths': '105',
#   'aadr': '11.0'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'District of Columbia',
#   'deaths': '37',
#   'aadr': '5.6'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Florida',
#   'deaths': '2880',
#   'aadr': '13.9'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Georgia',
#   'deaths': '1157',
#   'aadr': '11.7'},
#  {'year': '2011',
#   '_113_cause_name': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Hawaii',
#   'deaths': '181',
#   'aadr': '12.8'},
#  ...]

# %%
results_df = pd.DataFrame(loaded_json)
results_df.head()
# Out:
#    year                                    _113_cause_name  \
# 0  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2010  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2010  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                cause_name       state deaths  aadr
# 0  Unintentional injuries     Alabama   2394  49.6
# 1  Unintentional injuries      Alaska    366  58.7
# 2  Unintentional injuries     Arizona   3018  46.7
# 3  Unintentional injuries    Arkansas   1461  49.4
# 4  Unintentional injuries  California  10435  27.8

# %%
results_df.count()
# Out:
# year               4576
# _113_cause_name    4576
# cause_name         4576
# state              4576
# deaths             4576
# aadr               4576
# dtype: int64

# %%
death_cause=results_df.drop(columns='_113_cause_name')
death_cause
# Out:
#       year              cause_name          state deaths  aadr
# 0     2010  Unintentional injuries        Alabama   2394  49.6
# 1     2010  Unintentional injuries         Alaska    366  58.7
# 2     2010  Unintentional injuries        Arizona   3018  46.7
# 3     2010  Unintentional injuries       Arkansas   1461  49.4
# 4     2010  Unintentional injuries     California  10435  27.8
# ...    ...                     ...            ...    ...   ...
# 4571  2017          Kidney disease       Virginia   1618  16.9
# 4572  2017          Kidney disease     Washington    439   5.3
# 4573  2017          Kidney disease  West Virginia    436  17.1
# 4574  2017          Kidney disease      Wisconsin    922  12.5
# 4575  2017          Kidney disease        Wyoming     63   9.5
#
# [4576 rows x 5 columns]

# %% [markdown]
# # Scrape coordinates of the states using BeautifulSoup

# %%
url="https://www.latlong.net/category/states-236-14.html"
lat_lng = pd.read_html(url)

# %%
#Read the html table as dataframe
coordinates_df=lat_lng[0]
#Rename state column to cross-reference with death_cause dataset
coordinates_df=coordinates_df.rename(columns = {"Place Name" : "state"})
coordinates_df.Longitude.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Check the key (state) for merging and format its values for uniformity in both dfs

# %%
#Strip string(', the USA') from state to have identical values in both dataframes
coordinates_df['state']=coordinates_df['state'].str.split(',').str[0]
coordinates_df.head()
# Out:
#            state  Latitude   Longitude
# 0      Wisconsin      44.5  -89.500000
# 1  West Virginia      39.0  -80.500000
# 2        Vermont      44.0  -72.699997
# 3          Texas      31.0 -100.000000
# 4   South Dakota      44.5 -100.000000

# %%
#check length of unique values for state in death_cause df
states_death=death_cause['state'].unique()
len(states_death)
# states_death
# Out:
# 52

# %%
#check length of unique values for state in coordinates_df
states_coord=coordinates_df['state'].unique()
len(states_coord)
# states_coord
# Out:
# 50

# %%
#Check the difference in unique values in state column for both dataframe
list(set(states_death) - set(states_coord))
# Out:
# ['Missouri', 'United States', 'District of Columbia']

# %%
#Drop United states from death_cause df (create a df that doesn't contain the specified value)
death_cause=death_cause[death_cause.state!='United States']
states_death=death_cause['state'].unique()
len(states_death)
# Out:
# 51

# %%
# appending a new row for District of Columbia
# when values were passed as scalar, said "ValueError: If using all scalar values, you must pass an index”. 
# Hence, the values are passed as an array
dc_lat_lng = pd.DataFrame({"state":["District of Columbia"], 
                         "Latitude":[38.9072],
                        "Longitude":[-77.0369]}) 

coordinates_df=coordinates_df.append(dc_lat_lng, ignore_index=True)

# %%
#Change Missouri State to Missouri
coordinates_df=coordinates_df.replace("Missouri State", "Missouri")
states_coord=coordinates_df['state'].unique()
len(states_coord)
# Out:
# 51

# %%
#Recheck for difference
list(set(states_death) - set(states_coord))
# Out:
# []

# %%
#Merge the two dataframes
death_cause_with_coordinates=pd.merge(death_cause,coordinates_df, on='state')
death_cause_with_coordinates
# Out:
#       year               cause_name    state deaths   aadr  Latitude  \
# 0     2010   Unintentional injuries  Alabama   2394   49.6  32.31823
# 1     2010               All causes  Alabama  48038  939.7  32.31823
# 2     2010      Alzheimer's disease  Alabama   1523   31.2  32.31823
# 3     2010                   Stroke  Alabama   2619   51.6  32.31823
# 4     2010                     CLRD  Alabama   2866   55.4  32.31823
# ...    ...                      ...      ...    ...    ...       ...
# 4483  2017            Heart disease  Wyoming   1001  148.9  43.07597
# 4484  2017  Influenza and pneumonia  Wyoming    115   17.5  43.07597
# 4485  2017                  Suicide  Wyoming    157   26.9  43.07597
# 4486  2017                   Cancer  Wyoming    948  136.1  43.07597
# 4487  2017           Kidney disease  Wyoming     63    9.5  43.07597
#
#        Longitude
# 0     -86.902298
# 1     -86.902298
# 2     -86.902298
# 3     -86.902298
# 4     -86.902298
# ...          ...
# 4483 -107.290283
# 4484 -107.290283
# 4485 -107.290283
# 4486 -107.290283
# 4487 -107.290283
#
# [4488 rows x 7 columns]

# %%
#Check for any null values and sum them up to give total nos.
death_cause_with_coordinates.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Load data to MongoDB cloud

# %% [markdown]
# Create account in MongoDB Atlas and set up credentials to connect and deploy database in cluster. For GUI, install Compass or use command line to access database.

# %%
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs and establish connection with the cluster in cloud using id and password
conn = os.environ.get('MONGODB_URI', '') or "mongodb+srv://<username>:<password>@cluster0-v6uxh.mongodb.net/test?retryWrites=true&w=majority"
client = pymongo.MongoClient(conn)
conn
# Out:
# 'mongodb+srv://Harmeet:harmeet123@cluster0-v6uxh.mongodb.net/test?retryWrites=true&w=majority'

# %%
# Define database and collection
db = client.complete_death_coord_data
mortality_records = db.death_cause_with_coordinates

# %%
#Code to check connection,troubleshooting. Comment out.  
# testclient = pymongo.MongoClient(conn)
# testdb = testclient.project2
# try: testdb.command("serverStatus")
# except Exception as e: print(e)
# else: print("You are connected!")
# testclient.close()

# %%
#Add data to the database in cluster
db.mortality_records.insert_many(death_cause_with_coordinates.to_dict('records'))

# %%
#Read data from cluster
records=db.mortality_records.find()
for record in records:
    print(record)
# Out:
# {'_id': ObjectId('5df979a0779d988a092769c2'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2394', 'aadr': '49.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769c3'), 'year': '2010', 'cause_name': 'All causes', 'state': 'Alabama', 'deaths': '48038', 'aadr': '939.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769c4'), 'year': '2010', 'cause_name': "Alzheimer's disease", 'state': 'Alabama', 'deaths': '1523', 'aadr': '31.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769c5'), 'year': '2010', 'cause_name': 'Stroke', 'state': 'Alabama', 'deaths': '2619', 'aadr': '51.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769c6'), 'year': '2010', 'cause_name': 'CLRD', 'state': 'Alabama', 'deaths': '2866', 'aadr': '55.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769c7'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Alabama', 'deaths': '1302', 'aadr': '25.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769c8'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '12083', 'aadr': '236.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769c9'), 'year': '2010', 'cause_name': 'Influenza and pneumonia', 'state': 'Alabama', 'deaths': '942', 'aadr': '18.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769ca'), 'year': '2010', 'cause_name': 'Suicide', 'state': 'Alabama', 'deaths': '679', 'aadr': '14.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769cb'), 'year': '2010', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10196', 'aadr': '191.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769cc'), 'year': '2010', 'cause_name': 'Kidney disease', 'state': 'Alabama', 'deaths': '1184', 'aadr': '23.1', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769cd'), 'year': '2011', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2662', 'aadr': '54.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769ce'), 'year': '2011', 'cause_name': 'All causes', 'state': 'Alabama', 'deaths': '48681', 'aadr': '933.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769cf'), 'year': '2011', 'cause_name': "Alzheimer's disease", 'state': 'Alabama', 'deaths': '1486', 'aadr': '29.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d0'), 'year': '2011', 'cause_name': 'Stroke', 'state': 'Alabama', 'deaths': '2568', 'aadr': '49.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d1'), 'year': '2011', 'cause_name': 'CLRD', 'state': 'Alabama', 'deaths': '2912', 'aadr': '55.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d2'), 'year': '2011', 'cause_name': 'Diabetes', 'state': 'Alabama', 'deaths': '1278', 'aadr': '23.9', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d3'), 'year': '2011', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '11942', 'aadr': '228.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d4'), 'year': '2011', 'cause_name': 'Influenza and pneumonia', 'state': 'Alabama', 'deaths': '951', 'aadr': '18.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d5'), 'year': '2011', 'cause_name': 'Suicide', 'state': 'Alabama', 'deaths': '654', 'aadr': '13.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d6'), 'year': '2011', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10233', 'aadr': '187.8', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d7'), 'year': '2011', 'cause_name': 'Kidney disease', 'state': 'Alabama', 'deaths': '1047', 'aadr': '20.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d8'), 'year': '2012', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2283', 'aadr': '46.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769d9'), 'year': '2012', 'cause_name': 'All causes', 'state': 'Alabama', 'deaths': '49301', 'aadr': '926.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769da'), 'year': '2012', 'cause_name': "Alzheimer's disease", 'state': 'Alabama', 'deaths': '1390', 'aadr': '27.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769db'), 'year': '2012', 'cause_name': 'Stroke', 'state': 'Alabama', 'deaths': '2628', 'aadr': '49.5', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769dc'), 'year': '2012', 'cause_name': 'CLRD', 'state': 'Alabama', 'deaths': '3015', 'aadr': '55.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769dd'), 'year': '2012', 'cause_name': 'Diabetes', 'state': 'Alabama', 'deaths': '1300', 'aadr': '23.9', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769de'), 'year': '2012', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '12036', 'aadr': '225.1', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769df'), 'year': '2012', 'cause_name': 'Influenza and pneumonia', 'state': 'Alabama', 'deaths': '942', 'aadr': '17.9', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e0'), 'year': '2012', 'cause_name': 'Suicide', 'state': 'Alabama', 'deaths': '724', 'aadr': '14.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e1'), 'year': '2012', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10276', 'aadr': '185.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e2'), 'year': '2012', 'cause_name': 'Kidney disease', 'state': 'Alabama', 'deaths': '1035', 'aadr': '19.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e3'), 'year': '2013', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2329', 'aadr': '47.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e4'), 'year': '2013', 'cause_name': 'All causes', 'state': 'Alabama', 'deaths': '50189', 'aadr': '925.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e5'), 'year': '2013', 'cause_name': "Alzheimer's disease", 'state': 'Alabama', 'deaths': '1398', 'aadr': '26.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e6'), 'year': '2013', 'cause_name': 'Stroke', 'state': 'Alabama', 'deaths': '2604', 'aadr': '48.1', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e7'), 'year': '2013', 'cause_name': 'CLRD', 'state': 'Alabama', 'deaths': '3043', 'aadr': '54.8', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e8'), 'year': '2013', 'cause_name': 'Diabetes', 'state': 'Alabama', 'deaths': '1349', 'aadr': '24.3', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769e9'), 'year': '2013', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '12472', 'aadr': '228.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769ea'), 'year': '2013', 'cause_name': 'Influenza and pneumonia', 'state': 'Alabama', 'deaths': '1035', 'aadr': '19.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769eb'), 'year': '2013', 'cause_name': 'Suicide', 'state': 'Alabama', 'deaths': '721', 'aadr': '14.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769ec'), 'year': '2013', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10328', 'aadr': '182.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769ed'), 'year': '2013', 'cause_name': 'Kidney disease', 'state': 'Alabama', 'deaths': '1057', 'aadr': '19.3', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769ee'), 'year': '2014', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2463', 'aadr': '49.3', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769ef'), 'year': '2014', 'cause_name': 'All causes', 'state': 'Alabama', 'deaths': '50215', 'aadr': '909.1', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f0'), 'year': '2014', 'cause_name': "Alzheimer's disease", 'state': 'Alabama', 'deaths': '1885', 'aadr': '35.3', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f1'), 'year': '2014', 'cause_name': 'Stroke', 'state': 'Alabama', 'deaths': '2663', 'aadr': '48.3', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f2'), 'year': '2014', 'cause_name': 'CLRD', 'state': 'Alabama', 'deaths': '3050', 'aadr': '53.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f3'), 'year': '2014', 'cause_name': 'Diabetes', 'state': 'Alabama', 'deaths': '1281', 'aadr': '22.8', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f4'), 'year': '2014', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '12461', 'aadr': '224.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f5'), 'year': '2014', 'cause_name': 'Influenza and pneumonia', 'state': 'Alabama', 'deaths': '1031', 'aadr': '18.8', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f6'), 'year': '2014', 'cause_name': 'Suicide', 'state': 'Alabama', 'deaths': '715', 'aadr': '14.5', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f7'), 'year': '2014', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10286', 'aadr': '177.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f8'), 'year': '2014', 'cause_name': 'Kidney disease', 'state': 'Alabama', 'deaths': '1011', 'aadr': '18.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769f9'), 'year': '2015', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2552', 'aadr': '50.9', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769fa'), 'year': '2015', 'cause_name': 'All causes', 'state': 'Alabama', 'deaths': '51909', 'aadr': '924.5', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769fb'), 'year': '2015', 'cause_name': "Alzheimer's disease", 'state': 'Alabama', 'deaths': '2282', 'aadr': '41.8', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769fc'), 'year': '2015', 'cause_name': 'Stroke', 'state': 'Alabama', 'deaths': '2937', 'aadr': '52.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769fd'), 'year': '2015', 'cause_name': 'CLRD', 'state': 'Alabama', 'deaths': '3279', 'aadr': '56.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769fe'), 'year': '2015', 'cause_name': 'Diabetes', 'state': 'Alabama', 'deaths': '1255', 'aadr': '21.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a092769ff'), 'year': '2015', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '12981', 'aadr': '229.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a00'), 'year': '2015', 'cause_name': 'Influenza and pneumonia', 'state': 'Alabama', 'deaths': '1097', 'aadr': '19.5', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a01'), 'year': '2015', 'cause_name': 'Suicide', 'state': 'Alabama', 'deaths': '750', 'aadr': '14.9', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a02'), 'year': '2015', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10354', 'aadr': '175.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a03'), 'year': '2015', 'cause_name': 'Kidney disease', 'state': 'Alabama', 'deaths': '1040', 'aadr': '18.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a04'), 'year': '2016', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2755', 'aadr': '55.5', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a05'), 'year': '2016', 'cause_name': 'All causes', 'state': 'Alabama', 'deaths': '52466', 'aadr': '920.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a06'), 'year': '2016', 'cause_name': "Alzheimer's disease", 'state': 'Alabama', 'deaths': '2507', 'aadr': '45.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a07'), 'year': '2016', 'cause_name': 'Stroke', 'state': 'Alabama', 'deaths': '2967', 'aadr': '51.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a08'), 'year': '2016', 'cause_name': 'CLRD', 'state': 'Alabama', 'deaths': '3326', 'aadr': '56.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a09'), 'year': '2016', 'cause_name': 'Diabetes', 'state': 'Alabama', 'deaths': '1183', 'aadr': '20.1', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a0a'), 'year': '2016', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '12832', 'aadr': '222.5', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a0b'), 'year': '2016', 'cause_name': 'Influenza and pneumonia', 'state': 'Alabama', 'deaths': '987', 'aadr': '17.1', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a0c'), 'year': '2016', 'cause_name': 'Suicide', 'state': 'Alabama', 'deaths': '788', 'aadr': '15.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a0d'), 'year': '2016', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10419', 'aadr': '174.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a0e'), 'year': '2016', 'cause_name': 'Kidney disease', 'state': 'Alabama', 'deaths': '1012', 'aadr': '17.4', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a0f'), 'year': '2017', 'cause_name': 'Unintentional injuries', 'state': 'Alabama', 'deaths': '2703', 'aadr': '53.8', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a10'), 'year': '2017', 'cause_name': 'All causes', 'state': 'Alabama', 'deaths': '53238', 'aadr': '917.7', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a11'), 'year': '2017', 'cause_name': "Alzheimer's disease", 'state': 'Alabama', 'deaths': '2563', 'aadr': '45.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a12'), 'year': '2017', 'cause_name': 'Stroke', 'state': 'Alabama', 'deaths': '2931', 'aadr': '50.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a13'), 'year': '2017', 'cause_name': 'CLRD', 'state': 'Alabama', 'deaths': '3484', 'aadr': '57.8', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a14'), 'year': '2017', 'cause_name': 'Diabetes', 'state': 'Alabama', 'deaths': '1173', 'aadr': '19.8', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a15'), 'year': '2017', 'cause_name': 'Heart disease', 'state': 'Alabama', 'deaths': '13110', 'aadr': '223.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a16'), 'year': '2017', 'cause_name': 'Influenza and pneumonia', 'state': 'Alabama', 'deaths': '1176', 'aadr': '20.2', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a17'), 'year': '2017', 'cause_name': 'Suicide', 'state': 'Alabama', 'deaths': '836', 'aadr': '16.6', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a18'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'Alabama', 'deaths': '10410', 'aadr': '170.0', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a19'), 'year': '2017', 'cause_name': 'Kidney disease', 'state': 'Alabama', 'deaths': '980', 'aadr': '16.5', 'Latitude': 32.31823, 'Longitude': -86.902298}
# {'_id': ObjectId('5df979a0779d988a09276a1a'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '366', 'aadr': '58.7', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a1b'), 'year': '2010', 'cause_name': 'All causes', 'state': 'Alaska', 'deaths': '3728', 'aadr': '771.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a1c'), 'year': '2010', 'cause_name': "Alzheimer's disease", 'state': 'Alaska', 'deaths': '85', 'aadr': '25.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a1d'), 'year': '2010', 'cause_name': 'Stroke', 'state': 'Alaska', 'deaths': '167', 'aadr': '40.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a1e'), 'year': '2010', 'cause_name': 'CLRD', 'state': 'Alaska', 'deaths': '176', 'aadr': '41.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a1f'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Alaska', 'deaths': '86', 'aadr': '19.6', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a20'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '707', 'aadr': '151.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a21'), 'year': '2010', 'cause_name': 'Influenza and pneumonia', 'state': 'Alaska', 'deaths': '64', 'aadr': '15.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a22'), 'year': '2010', 'cause_name': 'Suicide', 'state': 'Alaska', 'deaths': '164', 'aadr': '22.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a23'), 'year': '2010', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '884', 'aadr': '176.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a24'), 'year': '2010', 'cause_name': 'Kidney disease', 'state': 'Alaska', 'deaths': '56', 'aadr': '13.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a25'), 'year': '2011', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '385', 'aadr': '57.3', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a26'), 'year': '2011', 'cause_name': 'All causes', 'state': 'Alaska', 'deaths': '3849', 'aadr': '747.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a27'), 'year': '2011', 'cause_name': "Alzheimer's disease", 'state': 'Alaska', 'deaths': '72', 'aadr': '20.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a28'), 'year': '2011', 'cause_name': 'Stroke', 'state': 'Alaska', 'deaths': '168', 'aadr': '39.4', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a29'), 'year': '2011', 'cause_name': 'CLRD', 'state': 'Alaska', 'deaths': '194', 'aadr': '41.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a2a'), 'year': '2011', 'cause_name': 'Diabetes', 'state': 'Alaska', 'deaths': '107', 'aadr': '20.6', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a2b'), 'year': '2011', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '739', 'aadr': '149.6', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a2c'), 'year': '2011', 'cause_name': 'Influenza and pneumonia', 'state': 'Alaska', 'deaths': '58', 'aadr': '12.6', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a2d'), 'year': '2011', 'cause_name': 'Suicide', 'state': 'Alaska', 'deaths': '143', 'aadr': '20.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a2e'), 'year': '2011', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '935', 'aadr': '175.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a2f'), 'year': '2011', 'cause_name': 'Kidney disease', 'state': 'Alaska', 'deaths': '53', 'aadr': '12.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a30'), 'year': '2012', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '368', 'aadr': '54.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a31'), 'year': '2012', 'cause_name': 'All causes', 'state': 'Alaska', 'deaths': '3912', 'aadr': '731.4', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a32'), 'year': '2012', 'cause_name': "Alzheimer's disease", 'state': 'Alaska', 'deaths': '102', 'aadr': '27.2', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a33'), 'year': '2012', 'cause_name': 'Stroke', 'state': 'Alaska', 'deaths': '188', 'aadr': '42.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a34'), 'year': '2012', 'cause_name': 'CLRD', 'state': 'Alaska', 'deaths': '189', 'aadr': '40.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a35'), 'year': '2012', 'cause_name': 'Diabetes', 'state': 'Alaska', 'deaths': '107', 'aadr': '18.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a36'), 'year': '2012', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '708', 'aadr': '136.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a37'), 'year': '2012', 'cause_name': 'Influenza and pneumonia', 'state': 'Alaska', 'deaths': '52', 'aadr': '10.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a38'), 'year': '2012', 'cause_name': 'Suicide', 'state': 'Alaska', 'deaths': '168', 'aadr': '23.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a39'), 'year': '2012', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '925', 'aadr': '166.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a3a'), 'year': '2012', 'cause_name': 'Kidney disease', 'state': 'Alaska', 'deaths': '44', 'aadr': '9.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a3b'), 'year': '2013', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '353', 'aadr': '52.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a3c'), 'year': '2013', 'cause_name': 'All causes', 'state': 'Alaska', 'deaths': '3997', 'aadr': '724.4', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a3d'), 'year': '2013', 'cause_name': "Alzheimer's disease", 'state': 'Alaska', 'deaths': '72', 'aadr': '18.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a3e'), 'year': '2013', 'cause_name': 'Stroke', 'state': 'Alaska', 'deaths': '189', 'aadr': '40.7', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a3f'), 'year': '2013', 'cause_name': 'CLRD', 'state': 'Alaska', 'deaths': '197', 'aadr': '37.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a40'), 'year': '2013', 'cause_name': 'Diabetes', 'state': 'Alaska', 'deaths': '112', 'aadr': '20.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a41'), 'year': '2013', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '706', 'aadr': '135.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a42'), 'year': '2013', 'cause_name': 'Influenza and pneumonia', 'state': 'Alaska', 'deaths': '66', 'aadr': '14.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a43'), 'year': '2013', 'cause_name': 'Suicide', 'state': 'Alaska', 'deaths': '171', 'aadr': '23.2', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a44'), 'year': '2013', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '1016', 'aadr': '172.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a45'), 'year': '2013', 'cause_name': 'Kidney disease', 'state': 'Alaska', 'deaths': '49', 'aadr': '10.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a46'), 'year': '2014', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '379', 'aadr': '55.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a47'), 'year': '2014', 'cause_name': 'All causes', 'state': 'Alaska', 'deaths': '4128', 'aadr': '736.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a48'), 'year': '2014', 'cause_name': "Alzheimer's disease", 'state': 'Alaska', 'deaths': '68', 'aadr': '17.2', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a49'), 'year': '2014', 'cause_name': 'Stroke', 'state': 'Alaska', 'deaths': '157', 'aadr': '32.3', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a4a'), 'year': '2014', 'cause_name': 'CLRD', 'state': 'Alaska', 'deaths': '192', 'aadr': '38.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a4b'), 'year': '2014', 'cause_name': 'Diabetes', 'state': 'Alaska', 'deaths': '113', 'aadr': '19.4', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a4c'), 'year': '2014', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '782', 'aadr': '146.6', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a4d'), 'year': '2014', 'cause_name': 'Influenza and pneumonia', 'state': 'Alaska', 'deaths': '68', 'aadr': '14.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a4e'), 'year': '2014', 'cause_name': 'Suicide', 'state': 'Alaska', 'deaths': '167', 'aadr': '22.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a4f'), 'year': '2014', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '972', 'aadr': '164.2', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a50'), 'year': '2014', 'cause_name': 'Kidney disease', 'state': 'Alaska', 'deaths': '45', 'aadr': '10.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a51'), 'year': '2015', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '388', 'aadr': '57.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a52'), 'year': '2015', 'cause_name': 'All causes', 'state': 'Alaska', 'deaths': '4316', 'aadr': '747.4', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a53'), 'year': '2015', 'cause_name': "Alzheimer's disease", 'state': 'Alaska', 'deaths': '68', 'aadr': '16.7', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a54'), 'year': '2015', 'cause_name': 'Stroke', 'state': 'Alaska', 'deaths': '182', 'aadr': '36.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a55'), 'year': '2015', 'cause_name': 'CLRD', 'state': 'Alaska', 'deaths': '204', 'aadr': '37.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a56'), 'year': '2015', 'cause_name': 'Diabetes', 'state': 'Alaska', 'deaths': '142', 'aadr': '23.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a57'), 'year': '2015', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '846', 'aadr': '154.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a58'), 'year': '2015', 'cause_name': 'Influenza and pneumonia', 'state': 'Alaska', 'deaths': '41', 'aadr': '8.4', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a59'), 'year': '2015', 'cause_name': 'Suicide', 'state': 'Alaska', 'deaths': '201', 'aadr': '26.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a5a'), 'year': '2015', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '978', 'aadr': '159.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a5b'), 'year': '2015', 'cause_name': 'Kidney disease', 'state': 'Alaska', 'deaths': '50', 'aadr': '10.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a5c'), 'year': '2016', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '439', 'aadr': '63.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a5d'), 'year': '2016', 'cause_name': 'All causes', 'state': 'Alaska', 'deaths': '4494', 'aadr': '745.6', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a5e'), 'year': '2016', 'cause_name': "Alzheimer's disease", 'state': 'Alaska', 'deaths': '111', 'aadr': '25.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a5f'), 'year': '2016', 'cause_name': 'Stroke', 'state': 'Alaska', 'deaths': '196', 'aadr': '39.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a60'), 'year': '2016', 'cause_name': 'CLRD', 'state': 'Alaska', 'deaths': '238', 'aadr': '41.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a61'), 'year': '2016', 'cause_name': 'Diabetes', 'state': 'Alaska', 'deaths': '124', 'aadr': '19.3', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a62'), 'year': '2016', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '831', 'aadr': '141.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a63'), 'year': '2016', 'cause_name': 'Influenza and pneumonia', 'state': 'Alaska', 'deaths': '61', 'aadr': '12.5', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a64'), 'year': '2016', 'cause_name': 'Suicide', 'state': 'Alaska', 'deaths': '193', 'aadr': '25.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a65'), 'year': '2016', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '995', 'aadr': '158.7', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a66'), 'year': '2016', 'cause_name': 'Kidney disease', 'state': 'Alaska', 'deaths': '53', 'aadr': '10.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a67'), 'year': '2017', 'cause_name': 'Unintentional injuries', 'state': 'Alaska', 'deaths': '436', 'aadr': '63.7', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a68'), 'year': '2017', 'cause_name': 'All causes', 'state': 'Alaska', 'deaths': '4411', 'aadr': '708.8', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a69'), 'year': '2017', 'cause_name': "Alzheimer's disease", 'state': 'Alaska', 'deaths': '98', 'aadr': '22.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a6a'), 'year': '2017', 'cause_name': 'Stroke', 'state': 'Alaska', 'deaths': '190', 'aadr': '35.1', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a6b'), 'year': '2017', 'cause_name': 'CLRD', 'state': 'Alaska', 'deaths': '204', 'aadr': '35.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a6c'), 'year': '2017', 'cause_name': 'Diabetes', 'state': 'Alaska', 'deaths': '130', 'aadr': '19.3', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a6d'), 'year': '2017', 'cause_name': 'Heart disease', 'state': 'Alaska', 'deaths': '814', 'aadr': '135.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a6e'), 'year': '2017', 'cause_name': 'Influenza and pneumonia', 'state': 'Alaska', 'deaths': '66', 'aadr': '11.7', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a6f'), 'year': '2017', 'cause_name': 'Suicide', 'state': 'Alaska', 'deaths': '200', 'aadr': '27.0', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a70'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'Alaska', 'deaths': '926', 'aadr': '139.2', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a71'), 'year': '2017', 'cause_name': 'Kidney disease', 'state': 'Alaska', 'deaths': '54', 'aadr': '9.9', 'Latitude': 66.160507, 'Longitude': -153.36914099999998}
# {'_id': ObjectId('5df979a0779d988a09276a72'), 'year': '2010', 'cause_name': 'Unintentional injuries', 'state': 'Arizona', 'deaths': '3018', 'aadr': '46.7', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a73'), 'year': '2010', 'cause_name': 'All causes', 'state': 'Arizona', 'deaths': '46762', 'aadr': '693.1', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a74'), 'year': '2010', 'cause_name': "Alzheimer's disease", 'state': 'Arizona', 'deaths': '2327', 'aadr': '35.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a75'), 'year': '2010', 'cause_name': 'Stroke', 'state': 'Arizona', 'deaths': '2138', 'aadr': '31.9', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a76'), 'year': '2010', 'cause_name': 'CLRD', 'state': 'Arizona', 'deaths': '2926', 'aadr': '43.1', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a77'), 'year': '2010', 'cause_name': 'Diabetes', 'state': 'Arizona', 'deaths': '1389', 'aadr': '20.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a78'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Arizona', 'deaths': '9954', 'aadr': '146.7', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a79'), 'year': '2010', 'cause_name': 'Influenza and pneumonia', 'state': 'Arizona', 'deaths': '768', 'aadr': '11.4', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a7a'), 'year': '2010', 'cause_name': 'Suicide', 'state': 'Arizona', 'deaths': '1093', 'aadr': '17.0', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a7b'), 'year': '2010', 'cause_name': 'Cancer', 'state': 'Arizona', 'deaths': '10678', 'aadr': '154.2', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a7c'), 'year': '2010', 'cause_name': 'Kidney disease', 'state': 'Arizona', 'deaths': '537', 'aadr': '7.9', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a7d'), 'year': '2011', 'cause_name': 'Unintentional injuries', 'state': 'Arizona', 'deaths': '3096', 'aadr': '46.8', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a7e'), 'year': '2011', 'cause_name': 'All causes', 'state': 'Arizona', 'deaths': '48381', 'aadr': '688.9', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a7f'), 'year': '2011', 'cause_name': "Alzheimer's disease", 'state': 'Arizona', 'deaths': '2348', 'aadr': '33.7', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a80'), 'year': '2011', 'cause_name': 'Stroke', 'state': 'Arizona', 'deaths': '2148', 'aadr': '30.6', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a81'), 'year': '2011', 'cause_name': 'CLRD', 'state': 'Arizona', 'deaths': '3166', 'aadr': '44.5', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a82'), 'year': '2011', 'cause_name': 'Diabetes', 'state': 'Arizona', 'deaths': '1740', 'aadr': '24.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a83'), 'year': '2011', 'cause_name': 'Heart disease', 'state': 'Arizona', 'deaths': '10662', 'aadr': '150.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a84'), 'year': '2011', 'cause_name': 'Influenza and pneumonia', 'state': 'Arizona', 'deaths': '690', 'aadr': '10.0', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a85'), 'year': '2011', 'cause_name': 'Suicide', 'state': 'Arizona', 'deaths': '1160', 'aadr': '17.8', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a86'), 'year': '2011', 'cause_name': 'Cancer', 'state': 'Arizona', 'deaths': '10690', 'aadr': '148.5', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a87'), 'year': '2011', 'cause_name': 'Kidney disease', 'state': 'Arizona', 'deaths': '395', 'aadr': '5.6', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a88'), 'year': '2012', 'cause_name': 'Unintentional injuries', 'state': 'Arizona', 'deaths': '3029', 'aadr': '45.1', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a89'), 'year': '2012', 'cause_name': 'All causes', 'state': 'Arizona', 'deaths': '49549', 'aadr': '682.9', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a8a'), 'year': '2012', 'cause_name': "Alzheimer's disease", 'state': 'Arizona', 'deaths': '2160', 'aadr': '30.0', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a8b'), 'year': '2012', 'cause_name': 'Stroke', 'state': 'Arizona', 'deaths': '2164', 'aadr': '29.9', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a8c'), 'year': '2012', 'cause_name': 'CLRD', 'state': 'Arizona', 'deaths': '3221', 'aadr': '43.6', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a8d'), 'year': '2012', 'cause_name': 'Diabetes', 'state': 'Arizona', 'deaths': '1736', 'aadr': '23.4', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a8e'), 'year': '2012', 'cause_name': 'Heart disease', 'state': 'Arizona', 'deaths': '10689', 'aadr': '145.5', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a8f'), 'year': '2012', 'cause_name': 'Influenza and pneumonia', 'state': 'Arizona', 'deaths': '683', 'aadr': '9.5', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a90'), 'year': '2012', 'cause_name': 'Suicide', 'state': 'Arizona', 'deaths': '1156', 'aadr': '17.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a91'), 'year': '2012', 'cause_name': 'Cancer', 'state': 'Arizona', 'deaths': '11085', 'aadr': '148.6', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a92'), 'year': '2012', 'cause_name': 'Kidney disease', 'state': 'Arizona', 'deaths': '414', 'aadr': '5.7', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a93'), 'year': '2013', 'cause_name': 'Unintentional injuries', 'state': 'Arizona', 'deaths': '3349', 'aadr': '48.6', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a94'), 'year': '2013', 'cause_name': 'All causes', 'state': 'Arizona', 'deaths': '50534', 'aadr': '674.2', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a95'), 'year': '2013', 'cause_name': "Alzheimer's disease", 'state': 'Arizona', 'deaths': '2383', 'aadr': '31.7', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a96'), 'year': '2013', 'cause_name': 'Stroke', 'state': 'Arizona', 'deaths': '2162', 'aadr': '28.6', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a97'), 'year': '2013', 'cause_name': 'CLRD', 'state': 'Arizona', 'deaths': '3345', 'aadr': '43.5', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a98'), 'year': '2013', 'cause_name': 'Diabetes', 'state': 'Arizona', 'deaths': '1786', 'aadr': '23.5', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a99'), 'year': '2013', 'cause_name': 'Heart disease', 'state': 'Arizona', 'deaths': '10755', 'aadr': '141.1', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a9a'), 'year': '2013', 'cause_name': 'Influenza and pneumonia', 'state': 'Arizona', 'deaths': '776', 'aadr': '10.4', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a9b'), 'year': '2013', 'cause_name': 'Suicide', 'state': 'Arizona', 'deaths': '1163', 'aadr': '17.5', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a9c'), 'year': '2013', 'cause_name': 'Cancer', 'state': 'Arizona', 'deaths': '11347', 'aadr': '147.0', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a9d'), 'year': '2013', 'cause_name': 'Kidney disease', 'state': 'Arizona', 'deaths': '374', 'aadr': '4.9', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a9e'), 'year': '2014', 'cause_name': 'Unintentional injuries', 'state': 'Arizona', 'deaths': '3322', 'aadr': '47.0', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276a9f'), 'year': '2014', 'cause_name': 'All causes', 'state': 'Arizona', 'deaths': '51538', 'aadr': '661.7', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa0'), 'year': '2014', 'cause_name': "Alzheimer's disease", 'state': 'Arizona', 'deaths': '2485', 'aadr': '31.6', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa1'), 'year': '2014', 'cause_name': 'Stroke', 'state': 'Arizona', 'deaths': '2235', 'aadr': '28.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa2'), 'year': '2014', 'cause_name': 'CLRD', 'state': 'Arizona', 'deaths': '3396', 'aadr': '42.2', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa3'), 'year': '2014', 'cause_name': 'Diabetes', 'state': 'Arizona', 'deaths': '1936', 'aadr': '24.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa4'), 'year': '2014', 'cause_name': 'Heart disease', 'state': 'Arizona', 'deaths': '10805', 'aadr': '136.4', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa5'), 'year': '2014', 'cause_name': 'Influenza and pneumonia', 'state': 'Arizona', 'deaths': '779', 'aadr': '10.0', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa6'), 'year': '2014', 'cause_name': 'Suicide', 'state': 'Arizona', 'deaths': '1244', 'aadr': '18.0', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa7'), 'year': '2014', 'cause_name': 'Cancer', 'state': 'Arizona', 'deaths': '11455', 'aadr': '142.7', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa8'), 'year': '2014', 'cause_name': 'Kidney disease', 'state': 'Arizona', 'deaths': '325', 'aadr': '4.1', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aa9'), 'year': '2015', 'cause_name': 'Unintentional injuries', 'state': 'Arizona', 'deaths': '3539', 'aadr': '49.2', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aaa'), 'year': '2015', 'cause_name': 'All causes', 'state': 'Arizona', 'deaths': '54299', 'aadr': '671.8', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aab'), 'year': '2015', 'cause_name': "Alzheimer's disease", 'state': 'Arizona', 'deaths': '2943', 'aadr': '35.8', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aac'), 'year': '2015', 'cause_name': 'Stroke', 'state': 'Arizona', 'deaths': '2522', 'aadr': '30.7', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aad'), 'year': '2015', 'cause_name': 'CLRD', 'state': 'Arizona', 'deaths': '3681', 'aadr': '43.8', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aae'), 'year': '2015', 'cause_name': 'Diabetes', 'state': 'Arizona', 'deaths': '2081', 'aadr': '25.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276aaf'), 'year': '2015', 'cause_name': 'Heart disease', 'state': 'Arizona', 'deaths': '11458', 'aadr': '138.8', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276ab0'), 'year': '2015', 'cause_name': 'Influenza and pneumonia', 'state': 'Arizona', 'deaths': '775', 'aadr': '9.5', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276ab1'), 'year': '2015', 'cause_name': 'Suicide', 'state': 'Arizona', 'deaths': '1276', 'aadr': '18.2', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# {'_id': ObjectId('5df979a0779d988a09276ab2'), 'year': '2015', 'cause_name': 'Cancer', 'state': 'Arizona', 'deaths': '11776', 'aadr': '141.3', 'Latitude': 34.048927, 'Longitude': -111.09373500000001}
# ...
# {'_id': ObjectId('5df979a0779d988a09277af8'), 'year': '2010', 'cause_name': 'Heart disease', 'state': 'Wyoming', 'deaths': '962', 'aadr': '169.8', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277af9'), 'year': '2010', 'cause_name': 'Influenza and pneumonia', 'state': 'Wyoming', 'deaths': '109', 'aadr': '19.5', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277afa'), 'year': '2010', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '131', 'aadr': '22.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277afb'), 'year': '2010', 'cause_name': 'Cancer', 'state': 'Wyoming', 'deaths': '1016', 'aadr': '172.6', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277afc'), 'year': '2010', 'cause_name': 'Kidney disease', 'state': 'Wyoming', 'deaths': '69', 'aadr': '12.5', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277afd'), 'year': '2011', 'cause_name': 'Unintentional injuries', 'state': 'Wyoming', 'deaths': '317', 'aadr': '56.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277afe'), 'year': '2011', 'cause_name': 'All causes', 'state': 'Wyoming', 'deaths': '4387', 'aadr': '754.6', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277aff'), 'year': '2011', 'cause_name': "Alzheimer's disease", 'state': 'Wyoming', 'deaths': '153', 'aadr': '27.7', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b00'), 'year': '2011', 'cause_name': 'Stroke', 'state': 'Wyoming', 'deaths': '214', 'aadr': '37.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b01'), 'year': '2011', 'cause_name': 'CLRD', 'state': 'Wyoming', 'deaths': '327', 'aadr': '57.0', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b02'), 'year': '2011', 'cause_name': 'Diabetes', 'state': 'Wyoming', 'deaths': '108', 'aadr': '18.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b03'), 'year': '2011', 'cause_name': 'Heart disease', 'state': 'Wyoming', 'deaths': '926', 'aadr': '158.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b04'), 'year': '2011', 'cause_name': 'Influenza and pneumonia', 'state': 'Wyoming', 'deaths': '116', 'aadr': '20.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b05'), 'year': '2011', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '132', 'aadr': '23.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b06'), 'year': '2011', 'cause_name': 'Cancer', 'state': 'Wyoming', 'deaths': '936', 'aadr': '156.0', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b07'), 'year': '2011', 'cause_name': 'Kidney disease', 'state': 'Wyoming', 'deaths': '85', 'aadr': '14.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b08'), 'year': '2012', 'cause_name': 'Unintentional injuries', 'state': 'Wyoming', 'deaths': '308', 'aadr': '52.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b09'), 'year': '2012', 'cause_name': 'All causes', 'state': 'Wyoming', 'deaths': '4481', 'aadr': '748.3', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b0a'), 'year': '2012', 'cause_name': "Alzheimer's disease", 'state': 'Wyoming', 'deaths': '123', 'aadr': '21.5', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b0b'), 'year': '2012', 'cause_name': 'Stroke', 'state': 'Wyoming', 'deaths': '205', 'aadr': '34.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b0c'), 'year': '2012', 'cause_name': 'CLRD', 'state': 'Wyoming', 'deaths': '334', 'aadr': '55.8', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b0d'), 'year': '2012', 'cause_name': 'Diabetes', 'state': 'Wyoming', 'deaths': '97', 'aadr': '15.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b0e'), 'year': '2012', 'cause_name': 'Heart disease', 'state': 'Wyoming', 'deaths': '1005', 'aadr': '167.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b0f'), 'year': '2012', 'cause_name': 'Influenza and pneumonia', 'state': 'Wyoming', 'deaths': '91', 'aadr': '15.7', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b10'), 'year': '2012', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '171', 'aadr': '29.6', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b11'), 'year': '2012', 'cause_name': 'Cancer', 'state': 'Wyoming', 'deaths': '955', 'aadr': '154.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b12'), 'year': '2012', 'cause_name': 'Kidney disease', 'state': 'Wyoming', 'deaths': '72', 'aadr': '12.3', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b13'), 'year': '2013', 'cause_name': 'Unintentional injuries', 'state': 'Wyoming', 'deaths': '325', 'aadr': '55.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b14'), 'year': '2013', 'cause_name': 'All causes', 'state': 'Wyoming', 'deaths': '4516', 'aadr': '731.7', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b15'), 'year': '2013', 'cause_name': "Alzheimer's disease", 'state': 'Wyoming', 'deaths': '126', 'aadr': '21.0', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b16'), 'year': '2013', 'cause_name': 'Stroke', 'state': 'Wyoming', 'deaths': '213', 'aadr': '35.1', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b17'), 'year': '2013', 'cause_name': 'CLRD', 'state': 'Wyoming', 'deaths': '387', 'aadr': '63.1', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b18'), 'year': '2013', 'cause_name': 'Diabetes', 'state': 'Wyoming', 'deaths': '89', 'aadr': '14.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b19'), 'year': '2013', 'cause_name': 'Heart disease', 'state': 'Wyoming', 'deaths': '939', 'aadr': '152.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b1a'), 'year': '2013', 'cause_name': 'Influenza and pneumonia', 'state': 'Wyoming', 'deaths': '112', 'aadr': '18.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b1b'), 'year': '2013', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '129', 'aadr': '21.5', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b1c'), 'year': '2013', 'cause_name': 'Cancer', 'state': 'Wyoming', 'deaths': '946', 'aadr': '148.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b1d'), 'year': '2013', 'cause_name': 'Kidney disease', 'state': 'Wyoming', 'deaths': '56', 'aadr': '9.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b1e'), 'year': '2014', 'cause_name': 'Unintentional injuries', 'state': 'Wyoming', 'deaths': '361', 'aadr': '60.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b1f'), 'year': '2014', 'cause_name': 'All causes', 'state': 'Wyoming', 'deaths': '4666', 'aadr': '742.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b20'), 'year': '2014', 'cause_name': "Alzheimer's disease", 'state': 'Wyoming', 'deaths': '162', 'aadr': '26.6', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b21'), 'year': '2014', 'cause_name': 'Stroke', 'state': 'Wyoming', 'deaths': '189', 'aadr': '30.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b22'), 'year': '2014', 'cause_name': 'CLRD', 'state': 'Wyoming', 'deaths': '343', 'aadr': '55.0', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b23'), 'year': '2014', 'cause_name': 'Diabetes', 'state': 'Wyoming', 'deaths': '110', 'aadr': '17.6', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b24'), 'year': '2014', 'cause_name': 'Heart disease', 'state': 'Wyoming', 'deaths': '1035', 'aadr': '162.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b25'), 'year': '2014', 'cause_name': 'Influenza and pneumonia', 'state': 'Wyoming', 'deaths': '113', 'aadr': '18.1', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b26'), 'year': '2014', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '120', 'aadr': '20.6', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b27'), 'year': '2014', 'cause_name': 'Cancer', 'state': 'Wyoming', 'deaths': '922', 'aadr': '140.7', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b28'), 'year': '2014', 'cause_name': 'Kidney disease', 'state': 'Wyoming', 'deaths': '78', 'aadr': '12.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b29'), 'year': '2015', 'cause_name': 'Unintentional injuries', 'state': 'Wyoming', 'deaths': '400', 'aadr': '65.8', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b2a'), 'year': '2015', 'cause_name': 'All causes', 'state': 'Wyoming', 'deaths': '4778', 'aadr': '748.3', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b2b'), 'year': '2015', 'cause_name': "Alzheimer's disease", 'state': 'Wyoming', 'deaths': '151', 'aadr': '24.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b2c'), 'year': '2015', 'cause_name': 'Stroke', 'state': 'Wyoming', 'deaths': '198', 'aadr': '31.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b2d'), 'year': '2015', 'cause_name': 'CLRD', 'state': 'Wyoming', 'deaths': '368', 'aadr': '57.1', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b2e'), 'year': '2015', 'cause_name': 'Diabetes', 'state': 'Wyoming', 'deaths': '136', 'aadr': '20.8', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b2f'), 'year': '2015', 'cause_name': 'Heart disease', 'state': 'Wyoming', 'deaths': '1030', 'aadr': '159.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b30'), 'year': '2015', 'cause_name': 'Influenza and pneumonia', 'state': 'Wyoming', 'deaths': '99', 'aadr': '16.0', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b31'), 'year': '2015', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '157', 'aadr': '28.0', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b32'), 'year': '2015', 'cause_name': 'Cancer', 'state': 'Wyoming', 'deaths': '931', 'aadr': '139.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b33'), 'year': '2015', 'cause_name': 'Kidney disease', 'state': 'Wyoming', 'deaths': '86', 'aadr': '13.3', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b34'), 'year': '2016', 'cause_name': 'Unintentional injuries', 'state': 'Wyoming', 'deaths': '371', 'aadr': '61.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b35'), 'year': '2016', 'cause_name': 'All causes', 'state': 'Wyoming', 'deaths': '4722', 'aadr': '720.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b36'), 'year': '2016', 'cause_name': "Alzheimer's disease", 'state': 'Wyoming', 'deaths': '138', 'aadr': '21.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b37'), 'year': '2016', 'cause_name': 'Stroke', 'state': 'Wyoming', 'deaths': '208', 'aadr': '31.7', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b38'), 'year': '2016', 'cause_name': 'CLRD', 'state': 'Wyoming', 'deaths': '327', 'aadr': '48.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b39'), 'year': '2016', 'cause_name': 'Diabetes', 'state': 'Wyoming', 'deaths': '112', 'aadr': '16.6', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b3a'), 'year': '2016', 'cause_name': 'Heart disease', 'state': 'Wyoming', 'deaths': '1051', 'aadr': '157.8', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b3b'), 'year': '2016', 'cause_name': 'Influenza and pneumonia', 'state': 'Wyoming', 'deaths': '99', 'aadr': '15.0', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b3c'), 'year': '2016', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '144', 'aadr': '25.2', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b3d'), 'year': '2016', 'cause_name': 'Cancer', 'state': 'Wyoming', 'deaths': '962', 'aadr': '140.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b3e'), 'year': '2016', 'cause_name': 'Kidney disease', 'state': 'Wyoming', 'deaths': '66', 'aadr': '10.0', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b3f'), 'year': '2017', 'cause_name': 'Unintentional injuries', 'state': 'Wyoming', 'deaths': '348', 'aadr': '56.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b40'), 'year': '2017', 'cause_name': 'All causes', 'state': 'Wyoming', 'deaths': '4768', 'aadr': '714.6', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b41'), 'year': '2017', 'cause_name': "Alzheimer's disease", 'state': 'Wyoming', 'deaths': '212', 'aadr': '32.7', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b42'), 'year': '2017', 'cause_name': 'Stroke', 'state': 'Wyoming', 'deaths': '190', 'aadr': '28.4', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b43'), 'year': '2017', 'cause_name': 'CLRD', 'state': 'Wyoming', 'deaths': '366', 'aadr': '53.8', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b44'), 'year': '2017', 'cause_name': 'Diabetes', 'state': 'Wyoming', 'deaths': '121', 'aadr': '18.1', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b45'), 'year': '2017', 'cause_name': 'Heart disease', 'state': 'Wyoming', 'deaths': '1001', 'aadr': '148.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b46'), 'year': '2017', 'cause_name': 'Influenza and pneumonia', 'state': 'Wyoming', 'deaths': '115', 'aadr': '17.5', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b47'), 'year': '2017', 'cause_name': 'Suicide', 'state': 'Wyoming', 'deaths': '157', 'aadr': '26.9', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b48'), 'year': '2017', 'cause_name': 'Cancer', 'state': 'Wyoming', 'deaths': '948', 'aadr': '136.1', 'Latitude': 43.07597, 'Longitude': -107.290283}
# {'_id': ObjectId('5df979a0779d988a09277b49'), 'year': '2017', 'cause_name': 'Kidney disease', 'state': 'Wyoming', 'deaths': '63', 'aadr': '9.5', 'Latitude': 43.07597, 'Longitude': -107.290283}
